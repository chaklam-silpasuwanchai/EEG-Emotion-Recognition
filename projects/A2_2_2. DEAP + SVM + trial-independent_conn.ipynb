# %% [markdown]
# ## 1. Self Written Feature Extraction
#
# In this file, I will use self-written connectivity feature extraction.

# %%
import time
import mne
import numpy as np
from tqdm.notebook import tqdm

from components.dataset_jo import *

dataset = Dataset_subjectDependent('data')
dataset.set_segment(60)
# for filename in dataset.get_file_list():
#     data, labels, _ = dataset.get_data(filename, return_type='numpy')
#     print(filename, labels.shape, labels.sum(axis=0)/labels.shape[0]*100)
# Out:
# Found: 32 files

# %%
def train_model(X_ori,y_ori,groups_ori,filename=None, kernel='rbf',return_text=False):
    
    # Make a copy because I am paranoid
    X,y,groups = X_ori.copy(), y_ori.copy(), groups_ori.copy()

    from sklearn.svm import SVC
    from sklearn.model_selection import GroupShuffleSplit 
    from sklearn.model_selection import cross_val_score

    model = SVC(kernel=kernel,max_iter=50000)
    cv = GroupShuffleSplit(n_splits=10, train_size=0.75, random_state=0)
    cross = cross_val_score(model, X, y, cv=cv,groups=groups, n_jobs=8)
    
    # We probably dont need this
    model = SVC(kernel=kernel, max_iter=50000)
    model.fit(X, y)
    ans = model.predict(X)
    acc = sum(ans == y) / len(y)
    # If the model answer with all 0 or 1, we print this message
    text = None
    if( sum(ans) == len(y) or sum(ans) == 0 ): 
        text = f"-----WARNING: Model {filename} failed to learn: sum(ans)={sum(ans)} sum(y)={sum(y)} len(y)={len(y)}"
    if(return_text):
        return model, acc, cross, text
    else:
        print(text)
        return model, acc, cross


def pearson_correlation(x,y):
    """ x,y denoted the signal_x and signal_y following the equation """
    cov = np.cov(x, y)
    # print(cov)
    # [[ 8806859.74527069  8007149.0906219 ] ==> [[cov_xx, cov_xy]
    # [ 8007149.0906219  10396797.72458848]]      [cov_yx, cov_yy]]
    cov_xy = cov[0,1] # or cov[1,0]
    cov_xx = cov[0,0]
    cov_yy = cov[1,1]
    corr = cov_xy / ( cov_xx**0.5 * cov_yy**0.5  )
    return corr

def _cal(p_id, partial_data):
    # print(f"p_id:{p_id} - data to run {partial_data.shape}")
    from itertools import combinations
    pcc = []
    for index in range(partial_data.shape[0]):
        pcc_epoch = []
        for comb in combinations(list(range(partial_data.shape[1])), 2):
            pcc_ab = pearson_correlation(partial_data[index, comb[0], :], partial_data[index, comb[1], :]   )
            pcc_epoch.append(pcc_ab)
        pcc_epoch = np.hstack(pcc_epoch)
        pcc.append(pcc_epoch)
    pcc = np.vstack(pcc)
    return pcc

def calculate_pcc(data, n_jobs=8):
    """ 
    Input: Expect data to have (n_epochs, n_channels, n_samples)
    Output: (n_epochs, n_conn ) => n_conn = n_channels!/(2!(n_channels-2)!)
    """
    from multiprocessing import Pool

    try:
        t_out = 60000
        pool = Pool()
        p_list = []
        ans_list = []
        num_p = n_jobs
        indices = np.array_split(np.arange(data.shape[0]), num_p)
        for p_id in range(num_p):
            p_list.append(pool.apply_async(_cal, [p_id, data[indices[p_id]] ]))
        for p_id in range(num_p):
            ans_list.append( p_list[p_id].get(timeout=t_out) )
        # ans_list
    except e:
        print(e)
    finally:
        print("========= close ========")
        pool.close() 
        pool.terminate()
    return np.vstack(ans_list)

# %%
data, labels, groups = dataset.get_data('s01', stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
data_csd = mne.preprocessing.compute_current_source_density(data)
pcc = calculate_pcc(data_csd.get_data())
pcc.shape
# Out:
# Not setting metadata
# 2400 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# p_id:0 - data to run (300, 32, 128)
# p_id:1 - data to run (300, 32, 128)
# p_id:2 - data to run (300, 32, 128)
# p_id:3 - data to run (300, 32, 128)
# p_id:4 - data to run (300, 32, 128)
# p_id:5 - data to run (300, 32, 128)
# p_id:6 - data to run (300, 32, 128)
# p_id:7 - data to run (300, 32, 128)
# ========= close ========
# (2400, 496)

# %% [markdown]
# ## 2. Connectivity

# %% [markdown]
# ### 2.1 $ \text{PCC}_{\text{time}}(i,j) = \frac{\text{Cov}[\mathbf{X}_i, \mathbf{X}_j]}{\sigma_{\mathbf{X}_i} \sigma_{\mathbf{X}_j}} $

# %%
accs, cv_means, cv_stds = [],[],[]
accs_v, cv_means_v, cv_stds_v = [],[],[]
reports = []
for filename in (pbar := tqdm(dataset.get_file_list())):
    start = time.time()
    pbar.set_description(filename)
    data, labels, groups = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
    data_csd = mne.preprocessing.compute_current_source_density(data)
    pcc = calculate_pcc(data_csd.get_data())
    _,acc,cross,train_report = train_model(pcc, labels.squeeze(), groups, filename=filename, return_text=True)
    report = f"\tAROUSAL-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs.append(acc)
    cv_means.append(cross.mean())
    cv_stds.append(cross.std())

    _, labels_v, groups_v = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_VALENCE, return_type='mne', sfreq=128)
    _,acc,cross,train_report = train_model(pcc, labels_v.squeeze(), groups_v, filename=filename, return_text=True)
    report = f"\tVALENCE-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs_v.append(acc)
    cv_means_v.append(cross.mean())
    cv_stds_v.append(cross.std())
    # break
    # count+=1
    # if(count == 5): break
report = f"AROUSAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}"
print(report)
reports.append(report)
report = f"VALENCE|Acc={sum(accs_v)/len(accs_v)}|10-CV={sum(cv_means_v)/len(cv_means_v)}|STD={sum(cv_stds_v)/len(cv_stds_v)}"
print(report)
reports.append(report)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s01|Acc=0.71042|10-CV=0.53583|STD=0.12882|Time spend=24.649158477783203
# 	VALENCE-s01|Acc=0.67917|10-CV=0.47867|STD=0.07076|Time spend=36.57502794265747
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s02|Acc=0.62083|10-CV=0.55067|STD=0.09966|Time spend=28.401918411254883
# 	VALENCE-s02|Acc=0.59125|10-CV=0.47917|STD=0.10006|Time spend=40.15917253494263
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s03|Acc=0.8|10-CV=0.73|STD=0.15524|Time spend=22.932647466659546
# 	VALENCE-s03|Acc=0.55042|10-CV=0.43967|STD=0.12141|Time spend=34.696168661117554
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s04|Acc=0.60208|10-CV=0.52133|STD=0.20422|Time spend=28.39444637298584
# 	VALENCE-s04|Acc=0.60042|10-CV=0.4905|STD=0.18738|Time spend=39.192758321762085
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s05|Acc=0.57417|10-CV=0.42483|STD=0.1069|Time spend=28.865741968154907
# 	VALENCE-s05|Acc=0.60208|10-CV=0.58633|STD=0.08869|Time spend=40.79992604255676
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s06|Acc=0.61125|10-CV=0.5235|STD=0.14029|Time spend=27.70300030708313
# 	VALENCE-s06|Acc=0.75|10-CV=0.72|STD=0.07483|Time spend=36.020861864089966
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s07|Acc=0.67333|10-CV=0.6235|STD=0.09409|Time spend=27.26369047164917
# 	VALENCE-s07|Acc=0.70292|10-CV=0.65833|STD=0.12437|Time spend=35.81617546081543
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s08|Acc=0.61583|10-CV=0.41367|STD=0.10197|Time spend=27.816514253616333
# 	VALENCE-s08|Acc=0.65667|10-CV=0.5|STD=0.084|Time spend=39.18985295295715
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s09|Acc=0.60625|10-CV=0.539|STD=0.11824|Time spend=28.036547422409058
# 	VALENCE-s09|Acc=0.62083|10-CV=0.52067|STD=0.14504|Time spend=39.28894805908203
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s10|Acc=0.63042|10-CV=0.506|STD=0.08261|Time spend=27.75631618499756
# 	VALENCE-s10|Acc=0.78833|10-CV=0.73417|STD=0.07562|Time spend=37.16130995750427
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s11|Acc=0.625|10-CV=0.6045|STD=0.06822|Time spend=26.712167024612427
# 	VALENCE-s11|Acc=0.61542|10-CV=0.53883|STD=0.15023|Time spend=37.390262603759766
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s12|Acc=0.825|10-CV=0.83|STD=0.1005|Time spend=24.46749711036682
# 	VALENCE-s12|Acc=0.63917|10-CV=0.45483|STD=0.14481|Time spend=35.49541163444519
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s13|Acc=0.85|10-CV=0.84|STD=0.06633|Time spend=22.472914218902588
# 	VALENCE-s13|Acc=0.6475|10-CV=0.572|STD=0.07999|Time spend=33.113943338394165
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s14|Acc=0.675|10-CV=0.65|STD=0.10247|Time spend=27.358490467071533
# 	VALENCE-s14|Acc=0.62667|10-CV=0.51133|STD=0.08787|Time spend=38.618101358413696
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s15|Acc=0.68792|10-CV=0.47417|STD=0.10481|Time spend=28.036670923233032
# 	VALENCE-s15|Acc=0.75|10-CV=0.68267|STD=0.06071|Time spend=36.89628267288208
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s16|Acc=0.68208|10-CV=0.45433|STD=0.10993|Time spend=28.46721911430359
# 	VALENCE-s16|Acc=0.71417|10-CV=0.641|STD=0.08687|Time spend=38.011072874069214
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s17|Acc=0.60208|10-CV=0.54783|STD=0.0775|Time spend=27.40619730949402
# 	VALENCE-s17|Acc=0.55|10-CV=0.41333|STD=0.08757|Time spend=39.45033669471741
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s18|Acc=0.62542|10-CV=0.545|STD=0.104|Time spend=27.338106632232666
# 	VALENCE-s18|Acc=0.72083|10-CV=0.63067|STD=0.12225|Time spend=36.56553363800049
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s19|Acc=0.675|10-CV=0.62717|STD=0.129|Time spend=26.412465810775757
# 	VALENCE-s19|Acc=0.61375|10-CV=0.453|STD=0.12522|Time spend=37.28353810310364
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s20|Acc=0.775|10-CV=0.82|STD=0.08718|Time spend=25.5428946018219
# 	VALENCE-s20|Acc=0.66667|10-CV=0.53767|STD=0.14521|Time spend=35.71930265426636
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.1|Time spend=25.300756216049194
# 	VALENCE-s21|Acc=0.525|10-CV=0.37883|STD=0.08466|Time spend=37.66263961791992
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s22|Acc=0.6|10-CV=0.61|STD=0.07|Time spend=28.486467123031616
# 	VALENCE-s22|Acc=0.62792|10-CV=0.59883|STD=0.09632|Time spend=39.81468176841736
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s23|Acc=0.75125|10-CV=0.77083|STD=0.08733|Time spend=24.24478054046631
# 	VALENCE-s23|Acc=0.73375|10-CV=0.58217|STD=0.10233|Time spend=33.569995403289795
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s24|Acc=0.825|10-CV=0.82|STD=0.07483|Time spend=24.019882678985596
# 	VALENCE-s24|Acc=0.57292|10-CV=0.4295|STD=0.18271|Time spend=36.122246980667114
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s25|Acc=0.725|10-CV=0.74|STD=0.12806|Time spend=25.663275480270386
# 	VALENCE-s25|Acc=0.52917|10-CV=0.3825|STD=0.10034|Time spend=37.90600824356079
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s26|Acc=0.5875|10-CV=0.53517|STD=0.11713|Time spend=28.945760488510132
# 	VALENCE-s26|Acc=0.65|10-CV=0.62|STD=0.14|Time spend=39.63161063194275
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s27|Acc=0.72208|10-CV=0.62817|STD=0.09782|Time spend=25.709702730178833
# 	VALENCE-s27|Acc=0.75|10-CV=0.667|STD=0.12287|Time spend=32.784738302230835
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s28|Acc=0.55333|10-CV=0.4355|STD=0.14079|Time spend=29.69543695449829
# 	VALENCE-s28|Acc=0.625|10-CV=0.57317|STD=0.15652|Time spend=40.32295083999634
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s29|Acc=0.64|10-CV=0.53017|STD=0.08703|Time spend=27.482006311416626
# 	VALENCE-s29|Acc=0.6425|10-CV=0.538|STD=0.09315|Time spend=38.51368308067322
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s30|Acc=0.58125|10-CV=0.4605|STD=0.06845|Time spend=28.50289011001587
# 	VALENCE-s30|Acc=0.675|10-CV=0.62|STD=0.14697|Time spend=38.12424039840698
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s31|Acc=0.69417|10-CV=0.58117|STD=0.14086|Time spend=27.92600679397583
# 	VALENCE-s31|Acc=0.64167|10-CV=0.49|STD=0.10733|Time spend=38.89612078666687
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s32|Acc=0.675|10-CV=0.74067|STD=0.12892|Time spend=26.653971433639526
# 	VALENCE-s32|Acc=0.60083|10-CV=0.43167|STD=0.11934|Time spend=37.84248924255371
# AROUSAL|Acc=0.6756770833333335|10-CV=0.606671875|STD=0.10697493467807011
# VALENCE|Acc=0.645625|10-CV=0.5423281249999999|STD=0.11298288071662489

# %%
for text in reports:
    if(text == None): continue
    print(text)
# Out:
# 	AROUSAL-s01|Acc=0.71042|10-CV=0.53583|STD=0.12882|Time spend=24.649158477783203
# 	VALENCE-s01|Acc=0.67917|10-CV=0.47867|STD=0.07076|Time spend=36.57502794265747
# 	AROUSAL-s02|Acc=0.62083|10-CV=0.55067|STD=0.09966|Time spend=28.401918411254883
# 	VALENCE-s02|Acc=0.59125|10-CV=0.47917|STD=0.10006|Time spend=40.15917253494263
# 	AROUSAL-s03|Acc=0.8|10-CV=0.73|STD=0.15524|Time spend=22.932647466659546
# -----WARNING: Model s03 failed to learn: sum(ans)=0.0 sum(y)=480.0 len(y)=2400
# 	VALENCE-s03|Acc=0.55042|10-CV=0.43967|STD=0.12141|Time spend=34.696168661117554
# 	AROUSAL-s04|Acc=0.60208|10-CV=0.52133|STD=0.20422|Time spend=28.39444637298584
# 	VALENCE-s04|Acc=0.60042|10-CV=0.4905|STD=0.18738|Time spend=39.192758321762085
# 	AROUSAL-s05|Acc=0.57417|10-CV=0.42483|STD=0.1069|Time spend=28.865741968154907
# 	VALENCE-s05|Acc=0.60208|10-CV=0.58633|STD=0.08869|Time spend=40.79992604255676
# 	AROUSAL-s06|Acc=0.61125|10-CV=0.5235|STD=0.14029|Time spend=27.70300030708313
# 	VALENCE-s06|Acc=0.75|10-CV=0.72|STD=0.07483|Time spend=36.020861864089966
# -----WARNING: Model s06 failed to learn: sum(ans)=2400.0 sum(y)=1800.0 len(y)=2400
# 	AROUSAL-s07|Acc=0.67333|10-CV=0.6235|STD=0.09409|Time spend=27.26369047164917
# 	VALENCE-s07|Acc=0.70292|10-CV=0.65833|STD=0.12437|Time spend=35.81617546081543
# 	AROUSAL-s08|Acc=0.61583|10-CV=0.41367|STD=0.10197|Time spend=27.816514253616333
# 	VALENCE-s08|Acc=0.65667|10-CV=0.5|STD=0.084|Time spend=39.18985295295715
# 	AROUSAL-s09|Acc=0.60625|10-CV=0.539|STD=0.11824|Time spend=28.036547422409058
# 	VALENCE-s09|Acc=0.62083|10-CV=0.52067|STD=0.14504|Time spend=39.28894805908203
# 	AROUSAL-s10|Acc=0.63042|10-CV=0.506|STD=0.08261|Time spend=27.75631618499756
# 	VALENCE-s10|Acc=0.78833|10-CV=0.73417|STD=0.07562|Time spend=37.16130995750427
# 	AROUSAL-s11|Acc=0.625|10-CV=0.6045|STD=0.06822|Time spend=26.712167024612427
# -----WARNING: Model s11 failed to learn: sum(ans)=0.0 sum(y)=900.0 len(y)=2400
# 	VALENCE-s11|Acc=0.61542|10-CV=0.53883|STD=0.15023|Time spend=37.390262603759766
# 	AROUSAL-s12|Acc=0.825|10-CV=0.83|STD=0.1005|Time spend=24.46749711036682
# -----WARNING: Model s12 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s12|Acc=0.63917|10-CV=0.45483|STD=0.14481|Time spend=35.49541163444519
# 	AROUSAL-s13|Acc=0.85|10-CV=0.84|STD=0.06633|Time spend=22.472914218902588
# -----WARNING: Model s13 failed to learn: sum(ans)=2400.0 sum(y)=2040.0 len(y)=2400
# 	VALENCE-s13|Acc=0.6475|10-CV=0.572|STD=0.07999|Time spend=33.113943338394165
# 	AROUSAL-s14|Acc=0.675|10-CV=0.65|STD=0.10247|Time spend=27.358490467071533
# -----WARNING: Model s14 failed to learn: sum(ans)=2400.0 sum(y)=1620.0 len(y)=2400
# 	VALENCE-s14|Acc=0.62667|10-CV=0.51133|STD=0.08787|Time spend=38.618101358413696
# 	AROUSAL-s15|Acc=0.68792|10-CV=0.47417|STD=0.10481|Time spend=28.036670923233032
# 	VALENCE-s15|Acc=0.75|10-CV=0.68267|STD=0.06071|Time spend=36.89628267288208
# 	AROUSAL-s16|Acc=0.68208|10-CV=0.45433|STD=0.10993|Time spend=28.46721911430359
# 	VALENCE-s16|Acc=0.71417|10-CV=0.641|STD=0.08687|Time spend=38.011072874069214
# 	AROUSAL-s17|Acc=0.60208|10-CV=0.54783|STD=0.0775|Time spend=27.40619730949402
# 	VALENCE-s17|Acc=0.55|10-CV=0.41333|STD=0.08757|Time spend=39.45033669471741
# -----WARNING: Model s17 failed to learn: sum(ans)=2400.0 sum(y)=1320.0 len(y)=2400
# 	AROUSAL-s18|Acc=0.62542|10-CV=0.545|STD=0.104|Time spend=27.338106632232666
# 	VALENCE-s18|Acc=0.72083|10-CV=0.63067|STD=0.12225|Time spend=36.56553363800049
# 	AROUSAL-s19|Acc=0.675|10-CV=0.62717|STD=0.129|Time spend=26.412465810775757
# -----WARNING: Model s19 failed to learn: sum(ans)=2400.0 sum(y)=1620.0 len(y)=2400
# 	VALENCE-s19|Acc=0.61375|10-CV=0.453|STD=0.12522|Time spend=37.28353810310364
# 	AROUSAL-s20|Acc=0.775|10-CV=0.82|STD=0.08718|Time spend=25.5428946018219
# -----WARNING: Model s20 failed to learn: sum(ans)=2400.0 sum(y)=1860.0 len(y)=2400
# 	VALENCE-s20|Acc=0.66667|10-CV=0.53767|STD=0.14521|Time spend=35.71930265426636
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.1|Time spend=25.300756216049194
# -----WARNING: Model s21 failed to learn: sum(ans)=2400.0 sum(y)=1920.0 len(y)=2400
# 	VALENCE-s21|Acc=0.525|10-CV=0.37883|STD=0.08466|Time spend=37.66263961791992
# -----WARNING: Model s21 failed to learn: sum(ans)=2400.0 sum(y)=1260.0 len(y)=2400
# 	AROUSAL-s22|Acc=0.6|10-CV=0.61|STD=0.07|Time spend=28.486467123031616
# -----WARNING: Model s22 failed to learn: sum(ans)=2400.0 sum(y)=1440.0 len(y)=2400
# 	VALENCE-s22|Acc=0.62792|10-CV=0.59883|STD=0.09632|Time spend=39.81468176841736
# 	AROUSAL-s23|Acc=0.75125|10-CV=0.77083|STD=0.08733|Time spend=24.24478054046631
# 	VALENCE-s23|Acc=0.73375|10-CV=0.58217|STD=0.10233|Time spend=33.569995403289795
# 	AROUSAL-s24|Acc=0.825|10-CV=0.82|STD=0.07483|Time spend=24.019882678985596
# -----WARNING: Model s24 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s24|Acc=0.57292|10-CV=0.4295|STD=0.18271|Time spend=36.122246980667114
# 	AROUSAL-s25|Acc=0.725|10-CV=0.74|STD=0.12806|Time spend=25.663275480270386
# -----WARNING: Model s25 failed to learn: sum(ans)=2400.0 sum(y)=1740.0 len(y)=2400
# 	VALENCE-s25|Acc=0.52917|10-CV=0.3825|STD=0.10034|Time spend=37.90600824356079
# 	AROUSAL-s26|Acc=0.5875|10-CV=0.53517|STD=0.11713|Time spend=28.945760488510132
# 	VALENCE-s26|Acc=0.65|10-CV=0.62|STD=0.14|Time spend=39.63161063194275
# -----WARNING: Model s26 failed to learn: sum(ans)=2400.0 sum(y)=1560.0 len(y)=2400
# 	AROUSAL-s27|Acc=0.72208|10-CV=0.62817|STD=0.09782|Time spend=25.709702730178833
# 	VALENCE-s27|Acc=0.75|10-CV=0.667|STD=0.12287|Time spend=32.784738302230835
# -----WARNING: Model s27 failed to learn: sum(ans)=2400.0 sum(y)=1800.0 len(y)=2400
# 	AROUSAL-s28|Acc=0.55333|10-CV=0.4355|STD=0.14079|Time spend=29.69543695449829
# 	VALENCE-s28|Acc=0.625|10-CV=0.57317|STD=0.15652|Time spend=40.32295083999634
# -----WARNING: Model s28 failed to learn: sum(ans)=2400.0 sum(y)=1500.0 len(y)=2400
# 	AROUSAL-s29|Acc=0.64|10-CV=0.53017|STD=0.08703|Time spend=27.482006311416626
# 	VALENCE-s29|Acc=0.6425|10-CV=0.538|STD=0.09315|Time spend=38.51368308067322
# 	AROUSAL-s30|Acc=0.58125|10-CV=0.4605|STD=0.06845|Time spend=28.50289011001587
# 	VALENCE-s30|Acc=0.675|10-CV=0.62|STD=0.14697|Time spend=38.12424039840698
# -----WARNING: Model s30 failed to learn: sum(ans)=2400.0 sum(y)=1620.0 len(y)=2400
# 	AROUSAL-s31|Acc=0.69417|10-CV=0.58117|STD=0.14086|Time spend=27.92600679397583
# 	VALENCE-s31|Acc=0.64167|10-CV=0.49|STD=0.10733|Time spend=38.89612078666687
# 	AROUSAL-s32|Acc=0.675|10-CV=0.74067|STD=0.12892|Time spend=26.653971433639526
# -----WARNING: Model s32 failed to learn: sum(ans)=2400.0 sum(y)=1620.0 len(y)=2400
# 	VALENCE-s32|Acc=0.60083|10-CV=0.43167|STD=0.11934|Time spend=37.84248924255371
# AROUSAL|Acc=0.6756770833333335|10-CV=0.606671875|STD=0.10697493467807011
# VALENCE|Acc=0.645625|10-CV=0.5423281249999999|STD=0.11298288071662489

# %%
accs.extend(accs_v)
cv_means.extend(cv_means_v)
cv_stds.extend(cv_stds_v)
print(f"TOTAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}")
# Out:
# TOTAL|Acc=0.6606510416666665|10-CV=0.5744999999999998|STD=0.1099789076973475

# %% [markdown]
# ### 2.2 $ \text{PCC}_{freq} (i,j) = \frac{\text{Cov}[\hat{\mathbf{X}}_i, \hat{\mathbf{X}}_j]}{\sigma_{\hat{\mathbf{X}}_i} \sigma_{\hat{\mathbf{X}}_j}} $

# %%
def calculate_fft(signal, sfreq):
    """ signal: can be 1D array of (n_sample,) or 2D array of (n_signal, n_sample)  """
    number_sample = signal.shape[-1]

    # the result will be a complex number. We can obtain the magnitude using `absolute`
    magnitude = np.abs(np.fft.fft(signal))
    # scale the result
    magnitude = magnitude / (number_sample/2)
    # Selecting the range
    magnitude = magnitude.T[:number_sample//2].T
    freq_range = np.fft.fftfreq(number_sample, d=1/sfreq)[:number_sample//2]

    return magnitude, freq_range

# %%
accs, cv_means, cv_stds = [],[],[]
accs_v, cv_means_v, cv_stds_v = [],[],[]
reports = []
for filename in (pbar := tqdm(dataset.get_file_list())):
    start = time.time()
    pbar.set_description(filename)
    data, labels, groups = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
    
    data_csd = mne.preprocessing.compute_current_source_density(data)
    magnitude, freq_range = calculate_fft(data_csd.get_data(), 128)
    pcc = calculate_pcc(magnitude)
    _,acc,cross,train_report = train_model(pcc, labels.squeeze(), groups, filename=filename, return_text=True)
    report = f"\tAROUSAL-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs.append(acc)
    cv_means.append(cross.mean())
    cv_stds.append(cross.std())

    _, labels_v, groups_v = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_VALENCE, return_type='mne', sfreq=128)
    _,acc,cross,train_report = train_model(pcc, labels_v.squeeze(), groups_v, filename=filename, return_text=True)
    report = f"\tVALENCE-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs_v.append(acc)
    cv_means_v.append(cross.mean())
    cv_stds_v.append(cross.std())
    # break
    # count+=1
    # if(count == 5): break
report = f"AROUSAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}"
print(report)
reports.append(report)
report = f"VALENCE|Acc={sum(accs_v)/len(accs_v)}|10-CV={sum(cv_means_v)/len(cv_means_v)}|STD={sum(cv_stds_v)/len(cv_stds_v)}"
print(report)
reports.append(report)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s01|Acc=0.83458|10-CV=0.52183|STD=0.10863|Time spend=37.975125312805176
# 	VALENCE-s01|Acc=0.84583|10-CV=0.46983|STD=0.0456|Time spend=50.45032238960266
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s02|Acc=0.65208|10-CV=0.55033|STD=0.09151|Time spend=27.005324125289917
# 	VALENCE-s02|Acc=0.64042|10-CV=0.50117|STD=0.10106|Time spend=38.73914957046509
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s03|Acc=0.8|10-CV=0.73|STD=0.15524|Time spend=24.30398917198181
# 	VALENCE-s03|Acc=0.67917|10-CV=0.48067|STD=0.14263|Time spend=36.17456769943237
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s04|Acc=0.66083|10-CV=0.52367|STD=0.11386|Time spend=27.114458799362183
# 	VALENCE-s04|Acc=0.65833|10-CV=0.51033|STD=0.09498|Time spend=37.668662786483765
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s05|Acc=0.64458|10-CV=0.44317|STD=0.09782|Time spend=29.951061010360718
# 	VALENCE-s05|Acc=0.66167|10-CV=0.5635|STD=0.07306|Time spend=41.27688503265381
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s06|Acc=0.68083|10-CV=0.53033|STD=0.12093|Time spend=27.97029709815979
# 	VALENCE-s06|Acc=0.75083|10-CV=0.71833|STD=0.07516|Time spend=37.16634750366211
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s07|Acc=0.75583|10-CV=0.59433|STD=0.08101|Time spend=27.463313579559326
# 	VALENCE-s07|Acc=0.79|10-CV=0.653|STD=0.12481|Time spend=37.18470859527588
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s08|Acc=0.74875|10-CV=0.4145|STD=0.10897|Time spend=28.362992763519287
# 	VALENCE-s08|Acc=0.74458|10-CV=0.49467|STD=0.07264|Time spend=39.58238625526428
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s09|Acc=0.65792|10-CV=0.52983|STD=0.11255|Time spend=27.51101303100586
# 	VALENCE-s09|Acc=0.67792|10-CV=0.55483|STD=0.10324|Time spend=38.589701890945435
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s10|Acc=0.72375|10-CV=0.56717|STD=0.06408|Time spend=27.71075201034546
# 	VALENCE-s10|Acc=0.81792|10-CV=0.73517|STD=0.08099|Time spend=36.299689292907715
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s11|Acc=0.65667|10-CV=0.58717|STD=0.05227|Time spend=27.3175687789917
# 	VALENCE-s11|Acc=0.65958|10-CV=0.533|STD=0.13645|Time spend=38.25274586677551
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s12|Acc=0.825|10-CV=0.83|STD=0.1005|Time spend=24.31946110725403
# 	VALENCE-s12|Acc=0.69625|10-CV=0.49133|STD=0.13198|Time spend=35.13926720619202
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s13|Acc=0.85|10-CV=0.84|STD=0.06633|Time spend=23.733718872070312
# 	VALENCE-s13|Acc=0.69792|10-CV=0.554|STD=0.07551|Time spend=34.820271730422974
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s14|Acc=0.67583|10-CV=0.647|STD=0.10051|Time spend=26.938395977020264
# 	VALENCE-s14|Acc=0.70208|10-CV=0.5405|STD=0.06389|Time spend=38.09670352935791
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s15|Acc=0.77333|10-CV=0.50067|STD=0.09591|Time spend=27.991600513458252
# 	VALENCE-s15|Acc=0.81208|10-CV=0.687|STD=0.06675|Time spend=37.12032985687256
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s16|Acc=0.74458|10-CV=0.4525|STD=0.08515|Time spend=27.572978496551514
# 	VALENCE-s16|Acc=0.75042|10-CV=0.65183|STD=0.08827|Time spend=37.34369230270386
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s17|Acc=0.67042|10-CV=0.58633|STD=0.07076|Time spend=27.367997646331787
# 	VALENCE-s17|Acc=0.59917|10-CV=0.42283|STD=0.10111|Time spend=39.27334499359131
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s18|Acc=0.67875|10-CV=0.55183|STD=0.11038|Time spend=27.653496265411377
# 	VALENCE-s18|Acc=0.78042|10-CV=0.65283|STD=0.08987|Time spend=36.57676100730896
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s19|Acc=0.68833|10-CV=0.625|STD=0.12189|Time spend=27.01305651664734
# 	VALENCE-s19|Acc=0.6925|10-CV=0.45317|STD=0.11767|Time spend=38.28559923171997
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s20|Acc=0.775|10-CV=0.82|STD=0.08718|Time spend=26.584713220596313
# 	VALENCE-s20|Acc=0.74958|10-CV=0.54133|STD=0.12633|Time spend=37.36165118217468
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.1|Time spend=25.009672164916992
# 	VALENCE-s21|Acc=0.63083|10-CV=0.4045|STD=0.06731|Time spend=37.41444492340088
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s22|Acc=0.60042|10-CV=0.59433|STD=0.06347|Time spend=28.257025241851807
# 	VALENCE-s22|Acc=0.64917|10-CV=0.5935|STD=0.07483|Time spend=38.66374325752258
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s23|Acc=0.7675|10-CV=0.772|STD=0.08826|Time spend=25.823512077331543
# 	VALENCE-s23|Acc=0.78292|10-CV=0.571|STD=0.10574|Time spend=35.895211935043335
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s24|Acc=0.825|10-CV=0.82|STD=0.07483|Time spend=24.98308777809143
# 	VALENCE-s24|Acc=0.65917|10-CV=0.44233|STD=0.13497|Time spend=36.93884253501892
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s25|Acc=0.725|10-CV=0.74|STD=0.12806|Time spend=26.332233667373657
# 	VALENCE-s25|Acc=0.615|10-CV=0.3955|STD=0.09515|Time spend=38.38434290885925
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s26|Acc=0.67292|10-CV=0.51467|STD=0.09682|Time spend=28.2940514087677
# 	VALENCE-s26|Acc=0.67917|10-CV=0.5965|STD=0.1169|Time spend=39.31475329399109
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s27|Acc=0.79167|10-CV=0.62783|STD=0.09835|Time spend=26.255401134490967
# 	VALENCE-s27|Acc=0.79958|10-CV=0.66583|STD=0.11613|Time spend=34.4876868724823
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s28|Acc=0.58875|10-CV=0.44183|STD=0.08018|Time spend=29.09684467315674
# 	VALENCE-s28|Acc=0.63583|10-CV=0.54033|STD=0.11628|Time spend=39.80473351478577
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s29|Acc=0.68792|10-CV=0.53717|STD=0.08135|Time spend=27.221861839294434
# 	VALENCE-s29|Acc=0.69625|10-CV=0.53|STD=0.06776|Time spend=38.52683711051941
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s30|Acc=0.68|10-CV=0.47583|STD=0.07427|Time spend=28.676021337509155
# 	VALENCE-s30|Acc=0.67542|10-CV=0.61083|STD=0.13711|Time spend=38.901641845703125
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s31|Acc=0.77875|10-CV=0.575|STD=0.09615|Time spend=28.600401163101196
# 	VALENCE-s31|Acc=0.75542|10-CV=0.508|STD=0.09412|Time spend=40.58806109428406
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s32|Acc=0.70917|10-CV=0.67383|STD=0.09186|Time spend=26.762020587921143
# 	VALENCE-s32|Acc=0.66458|10-CV=0.4295|STD=0.09449|Time spend=39.306716442108154
# AROUSAL|Acc=0.7226302083333332|10-CV=0.6068177083333336|STD=0.09434588308914679
# VALENCE|Acc=0.7078125|10-CV=0.5467864583333334|STD=0.09789984048217981

# %%
for text in reports:
    if(text == None): continue
    print(text)

accs.extend(accs_v)
cv_means.extend(cv_means_v)
cv_stds.extend(cv_stds_v)
print(f"TOTAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}")
# Out:
# 	AROUSAL-s01|Acc=0.83458|10-CV=0.52183|STD=0.10863|Time spend=37.975125312805176
# 	VALENCE-s01|Acc=0.84583|10-CV=0.46983|STD=0.0456|Time spend=50.45032238960266
# 	AROUSAL-s02|Acc=0.65208|10-CV=0.55033|STD=0.09151|Time spend=27.005324125289917
# 	VALENCE-s02|Acc=0.64042|10-CV=0.50117|STD=0.10106|Time spend=38.73914957046509
# 	AROUSAL-s03|Acc=0.8|10-CV=0.73|STD=0.15524|Time spend=24.30398917198181
# -----WARNING: Model s03 failed to learn: sum(ans)=0.0 sum(y)=480.0 len(y)=2400
# 	VALENCE-s03|Acc=0.67917|10-CV=0.48067|STD=0.14263|Time spend=36.17456769943237
# 	AROUSAL-s04|Acc=0.66083|10-CV=0.52367|STD=0.11386|Time spend=27.114458799362183
# 	VALENCE-s04|Acc=0.65833|10-CV=0.51033|STD=0.09498|Time spend=37.668662786483765
# 	AROUSAL-s05|Acc=0.64458|10-CV=0.44317|STD=0.09782|Time spend=29.951061010360718
# 	VALENCE-s05|Acc=0.66167|10-CV=0.5635|STD=0.07306|Time spend=41.27688503265381
# 	AROUSAL-s06|Acc=0.68083|10-CV=0.53033|STD=0.12093|Time spend=27.97029709815979
# 	VALENCE-s06|Acc=0.75083|10-CV=0.71833|STD=0.07516|Time spend=37.16634750366211
# 	AROUSAL-s07|Acc=0.75583|10-CV=0.59433|STD=0.08101|Time spend=27.463313579559326
# 	VALENCE-s07|Acc=0.79|10-CV=0.653|STD=0.12481|Time spend=37.18470859527588
# 	AROUSAL-s08|Acc=0.74875|10-CV=0.4145|STD=0.10897|Time spend=28.362992763519287
# 	VALENCE-s08|Acc=0.74458|10-CV=0.49467|STD=0.07264|Time spend=39.58238625526428
# 	AROUSAL-s09|Acc=0.65792|10-CV=0.52983|STD=0.11255|Time spend=27.51101303100586
# 	VALENCE-s09|Acc=0.67792|10-CV=0.55483|STD=0.10324|Time spend=38.589701890945435
# 	AROUSAL-s10|Acc=0.72375|10-CV=0.56717|STD=0.06408|Time spend=27.71075201034546
# 	VALENCE-s10|Acc=0.81792|10-CV=0.73517|STD=0.08099|Time spend=36.299689292907715
# 	AROUSAL-s11|Acc=0.65667|10-CV=0.58717|STD=0.05227|Time spend=27.3175687789917
# 	VALENCE-s11|Acc=0.65958|10-CV=0.533|STD=0.13645|Time spend=38.25274586677551
# 	AROUSAL-s12|Acc=0.825|10-CV=0.83|STD=0.1005|Time spend=24.31946110725403
# -----WARNING: Model s12 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s12|Acc=0.69625|10-CV=0.49133|STD=0.13198|Time spend=35.13926720619202
# 	AROUSAL-s13|Acc=0.85|10-CV=0.84|STD=0.06633|Time spend=23.733718872070312
# -----WARNING: Model s13 failed to learn: sum(ans)=2400.0 sum(y)=2040.0 len(y)=2400
# 	VALENCE-s13|Acc=0.69792|10-CV=0.554|STD=0.07551|Time spend=34.820271730422974
# 	AROUSAL-s14|Acc=0.67583|10-CV=0.647|STD=0.10051|Time spend=26.938395977020264
# 	VALENCE-s14|Acc=0.70208|10-CV=0.5405|STD=0.06389|Time spend=38.09670352935791
# 	AROUSAL-s15|Acc=0.77333|10-CV=0.50067|STD=0.09591|Time spend=27.991600513458252
# 	VALENCE-s15|Acc=0.81208|10-CV=0.687|STD=0.06675|Time spend=37.12032985687256
# 	AROUSAL-s16|Acc=0.74458|10-CV=0.4525|STD=0.08515|Time spend=27.572978496551514
# 	VALENCE-s16|Acc=0.75042|10-CV=0.65183|STD=0.08827|Time spend=37.34369230270386
# 	AROUSAL-s17|Acc=0.67042|10-CV=0.58633|STD=0.07076|Time spend=27.367997646331787
# 	VALENCE-s17|Acc=0.59917|10-CV=0.42283|STD=0.10111|Time spend=39.27334499359131
# 	AROUSAL-s18|Acc=0.67875|10-CV=0.55183|STD=0.11038|Time spend=27.653496265411377
# 	VALENCE-s18|Acc=0.78042|10-CV=0.65283|STD=0.08987|Time spend=36.57676100730896
# 	AROUSAL-s19|Acc=0.68833|10-CV=0.625|STD=0.12189|Time spend=27.01305651664734
# 	VALENCE-s19|Acc=0.6925|10-CV=0.45317|STD=0.11767|Time spend=38.28559923171997
# 	AROUSAL-s20|Acc=0.775|10-CV=0.82|STD=0.08718|Time spend=26.584713220596313
# -----WARNING: Model s20 failed to learn: sum(ans)=2400.0 sum(y)=1860.0 len(y)=2400
# 	VALENCE-s20|Acc=0.74958|10-CV=0.54133|STD=0.12633|Time spend=37.36165118217468
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.1|Time spend=25.009672164916992
# -----WARNING: Model s21 failed to learn: sum(ans)=2400.0 sum(y)=1920.0 len(y)=2400
# 	VALENCE-s21|Acc=0.63083|10-CV=0.4045|STD=0.06731|Time spend=37.41444492340088
# 	AROUSAL-s22|Acc=0.60042|10-CV=0.59433|STD=0.06347|Time spend=28.257025241851807
# 	VALENCE-s22|Acc=0.64917|10-CV=0.5935|STD=0.07483|Time spend=38.66374325752258
# 	AROUSAL-s23|Acc=0.7675|10-CV=0.772|STD=0.08826|Time spend=25.823512077331543
# 	VALENCE-s23|Acc=0.78292|10-CV=0.571|STD=0.10574|Time spend=35.895211935043335
# 	AROUSAL-s24|Acc=0.825|10-CV=0.82|STD=0.07483|Time spend=24.98308777809143
# -----WARNING: Model s24 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s24|Acc=0.65917|10-CV=0.44233|STD=0.13497|Time spend=36.93884253501892
# 	AROUSAL-s25|Acc=0.725|10-CV=0.74|STD=0.12806|Time spend=26.332233667373657
# -----WARNING: Model s25 failed to learn: sum(ans)=2400.0 sum(y)=1740.0 len(y)=2400
# 	VALENCE-s25|Acc=0.615|10-CV=0.3955|STD=0.09515|Time spend=38.38434290885925
# 	AROUSAL-s26|Acc=0.67292|10-CV=0.51467|STD=0.09682|Time spend=28.2940514087677
# 	VALENCE-s26|Acc=0.67917|10-CV=0.5965|STD=0.1169|Time spend=39.31475329399109
# 	AROUSAL-s27|Acc=0.79167|10-CV=0.62783|STD=0.09835|Time spend=26.255401134490967
# 	VALENCE-s27|Acc=0.79958|10-CV=0.66583|STD=0.11613|Time spend=34.4876868724823
# 	AROUSAL-s28|Acc=0.58875|10-CV=0.44183|STD=0.08018|Time spend=29.09684467315674
# 	VALENCE-s28|Acc=0.63583|10-CV=0.54033|STD=0.11628|Time spend=39.80473351478577
# 	AROUSAL-s29|Acc=0.68792|10-CV=0.53717|STD=0.08135|Time spend=27.221861839294434
# 	VALENCE-s29|Acc=0.69625|10-CV=0.53|STD=0.06776|Time spend=38.52683711051941
# 	AROUSAL-s30|Acc=0.68|10-CV=0.47583|STD=0.07427|Time spend=28.676021337509155
# 	VALENCE-s30|Acc=0.67542|10-CV=0.61083|STD=0.13711|Time spend=38.901641845703125
# 	AROUSAL-s31|Acc=0.77875|10-CV=0.575|STD=0.09615|Time spend=28.600401163101196
# 	VALENCE-s31|Acc=0.75542|10-CV=0.508|STD=0.09412|Time spend=40.58806109428406
# 	AROUSAL-s32|Acc=0.70917|10-CV=0.67383|STD=0.09186|Time spend=26.762020587921143
# 	VALENCE-s32|Acc=0.66458|10-CV=0.4295|STD=0.09449|Time spend=39.306716442108154
# AROUSAL|Acc=0.7226302083333332|10-CV=0.6068177083333336|STD=0.09434588308914679
# VALENCE|Acc=0.7078125|10-CV=0.5467864583333334|STD=0.09789984048217981
# TOTAL|Acc=0.7152213541666667|10-CV=0.5768020833333335|STD=0.09612286178566334

# %% [markdown]
# ### 2.3 $ \text{PLV}(j,k) = \frac{1}{T} | \Sigma^{T}_{t=1} e^{i(\phi^{t}_{j} - \phi^{t}_{k})}   | $

# %%
# bands = [(0,4), (4,8), (8,12), (12,30), (30,64)]
def calculate_stft(signals, sfreq):
    from scipy import signal
    f_range, t_range, Z = signal.stft(signals, sfreq, nperseg=sfreq//10, nfft=sfreq)
    magnitude = np.abs(Z) 
    phase = np.angle(Z)
    return magnitude, phase, f_range, t_range

def PLV_stft(p_id, phase):
    # (32, 65, 12) => (channels, freqs, times)
    # print(f"p_id:{p_id} - data to run {phase.shape}")
    from itertools import combinations
    plv = []
    # count = 0
    for index in range(phase.shape[0]):
        plv_epoch = []
        for comb in combinations(list(range(phase.shape[1])), 2):
            # shape = (65,12)
            phase_a, phase_b = phase[index, comb[0]], phase[index, comb[1]]
            phase_diff = phase_a - phase_b
            # sum along the time size
            plv_ab = np.abs(np.average(np.exp(complex(0,1) * phase_diff), axis=1))
            plv_epoch.append(plv_ab)
        plv_epoch = np.vstack(plv_epoch)
        plv_epoch_5 = np.concatenate([ plv_epoch[:,0:4].mean(axis=1).reshape(-1,1),
                                        plv_epoch[:,4:8].mean(axis=1).reshape(-1,1),
                                        plv_epoch[:,8:12].mean(axis=1).reshape(-1,1),
                                        plv_epoch[:,12:30].mean(axis=1).reshape(-1,1),
                                        plv_epoch[:,30:65].mean(axis=1).reshape(-1,1)], axis=0)
        plv.append(np.expand_dims(plv_epoch_5, axis=0))
        # count += 1
        # if(count == 3): break
    # shape (496, 65)
    # 496 is number of pairs that is not duplicate
    # 65 is number of phase of frequencies
    plv = np.vstack( plv )
    return plv.squeeze()

def calculate_plv(data, n_jobs=8):
    """ 
    Input: Expect data to have (n_epochs, n_channels, n_samples)
    Output: (n_epochs, n_conn, n_freqs ) => n_conn = n_channels!/(2!(n_channels-2)!)
    """
    from multiprocessing import Pool

    try:
        t_out = 60000
        pool = Pool()
        p_list = []
        ans_list = []
        num_p = n_jobs
        indices = np.array_split(np.arange(data.shape[0]), num_p)
        _, phase, _, _ = calculate_stft(data, 128)
        for p_id in range(num_p):
            p_list.append(pool.apply_async(PLV_stft, [p_id, phase[indices[p_id]] ]))
        for p_id in range(num_p):
            ans_list.append( p_list[p_id].get(timeout=t_out) )
        # ans_list
    finally:
        print("========= close ========")
        pool.close() 
        pool.terminate()
    return np.vstack(ans_list)

# %%
data, labels, groups = dataset.get_data('s01', stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
data_csd = mne.preprocessing.compute_current_source_density(data)
plv = calculate_plv(data_csd.get_data(), n_jobs=8)
# _, phase, _, _ = calculate_stft(data_csd.get_data(), 128)
# plv = PLV_stft(1, phase)
plv.shape
del(plv)
# Out:
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 2480, 1)
# (300, 2480, 1)
# (300, 2480, 1)
# (300, 2480, 1)
# (300, 2480, 1)
# (300, 2480, 1)
# (300, 2480, 1)
# (300, 2480, 1)
# ========= close ========
# (2400, 2480)

# %%
accs, cv_means, cv_stds = [],[],[]
accs_v, cv_means_v, cv_stds_v = [],[],[]
reports = []
for filename in (pbar := tqdm(dataset.get_file_list())):
    start = time.time()
    pbar.set_description(filename)
    data, labels, groups = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
    
    data_csd = mne.preprocessing.compute_current_source_density(data)

    plv = calculate_plv(data_csd.get_data(), n_jobs=8)

    _,acc,cross,train_report = train_model(plv, labels.squeeze(), groups, filename=filename, return_text=True)
    report = f"\tAROUSAL-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs.append(acc)
    cv_means.append(cross.mean())
    cv_stds.append(cross.std())

    _, labels_v, groups_v = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_VALENCE, return_type='mne', sfreq=128)
    _,acc,cross,train_report = train_model(plv, labels_v.squeeze(), groups_v, filename=filename, return_text=True)
    report = f"\tVALENCE-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs_v.append(acc)
    cv_means_v.append(cross.mean())
    cv_stds_v.append(cross.std())
    # break
    # count+=1
    # if(count == 5): break
report = f"AROUSAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}"
print(report)
reports.append(report)
report = f"VALENCE|Acc={sum(accs_v)/len(accs_v)}|10-CV={sum(cv_means_v)/len(cv_means_v)}|STD={sum(cv_stds_v)/len(cv_stds_v)}"
print(report)
reports.append(report)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s01|Acc=0.89542|10-CV=0.55367|STD=0.11851|Time spend=109.13255429267883
# 	VALENCE-s01|Acc=0.90167|10-CV=0.4885|STD=0.0595|Time spend=174.95419669151306
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s02|Acc=0.70333|10-CV=0.52817|STD=0.0708|Time spend=93.1835834980011
# 	VALENCE-s02|Acc=0.74625|10-CV=0.662|STD=0.09903|Time spend=143.70813846588135
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s03|Acc=0.8|10-CV=0.73|STD=0.15524|Time spend=74.73655962944031
# 	VALENCE-s03|Acc=0.75875|10-CV=0.5405|STD=0.16141|Time spend=127.77436113357544
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s04|Acc=0.72625|10-CV=0.5345|STD=0.10676|Time spend=86.01233530044556
# 	VALENCE-s04|Acc=0.75667|10-CV=0.563|STD=0.07111|Time spend=133.91743230819702
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s05|Acc=0.72625|10-CV=0.46783|STD=0.0986|Time spend=91.03030467033386
# 	VALENCE-s05|Acc=0.73917|10-CV=0.55933|STD=0.07182|Time spend=143.22456979751587
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s06|Acc=0.6925|10-CV=0.50617|STD=0.11754|Time spend=88.44585251808167
# 	VALENCE-s06|Acc=0.75042|10-CV=0.71883|STD=0.07451|Time spend=134.34594178199768
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s07|Acc=0.82833|10-CV=0.588|STD=0.07728|Time spend=85.26484203338623
# 	VALENCE-s07|Acc=0.82292|10-CV=0.66283|STD=0.13512|Time spend=130.86327600479126
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s08|Acc=0.84042|10-CV=0.42|STD=0.11451|Time spend=86.62875556945801
# 	VALENCE-s08|Acc=0.85708|10-CV=0.50133|STD=0.06464|Time spend=140.87181997299194
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s09|Acc=0.73958|10-CV=0.49333|STD=0.08129|Time spend=81.36510443687439
# 	VALENCE-s09|Acc=0.77042|10-CV=0.62667|STD=0.09385|Time spend=126.49684929847717
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s10|Acc=0.80458|10-CV=0.6015|STD=0.07473|Time spend=84.9338390827179
# 	VALENCE-s10|Acc=0.8625|10-CV=0.77367|STD=0.0736|Time spend=124.2664623260498
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s11|Acc=0.67583|10-CV=0.56717|STD=0.05439|Time spend=81.67730498313904
# 	VALENCE-s11|Acc=0.69042|10-CV=0.53033|STD=0.12932|Time spend=131.80082988739014
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s12|Acc=0.825|10-CV=0.83|STD=0.1005|Time spend=72.30015683174133
# 	VALENCE-s12|Acc=0.74833|10-CV=0.53033|STD=0.11749|Time spend=123.34322381019592
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s13|Acc=0.85|10-CV=0.84|STD=0.06633|Time spend=63.10807967185974
# 	VALENCE-s13|Acc=0.775|10-CV=0.69933|STD=0.08051|Time spend=106.21433281898499
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s14|Acc=0.70042|10-CV=0.63033|STD=0.08913|Time spend=80.29607796669006
# 	VALENCE-s14|Acc=0.78958|10-CV=0.65633|STD=0.03735|Time spend=129.84347701072693
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s15|Acc=0.82667|10-CV=0.51633|STD=0.09797|Time spend=84.28204584121704
# 	VALENCE-s15|Acc=0.88542|10-CV=0.75|STD=0.06066|Time spend=124.8164415359497
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s16|Acc=0.80875|10-CV=0.50117|STD=0.06631|Time spend=84.05407285690308
# 	VALENCE-s16|Acc=0.78042|10-CV=0.64833|STD=0.09409|Time spend=130.70826888084412
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s17|Acc=0.75208|10-CV=0.62933|STD=0.03682|Time spend=78.18584752082825
# 	VALENCE-s17|Acc=0.67833|10-CV=0.45933|STD=0.09546|Time spend=132.13649225234985
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s18|Acc=0.71292|10-CV=0.52167|STD=0.11886|Time spend=82.87473154067993
# 	VALENCE-s18|Acc=0.82167|10-CV=0.69933|STD=0.06617|Time spend=120.6981680393219
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s19|Acc=0.73792|10-CV=0.62617|STD=0.11685|Time spend=81.6785340309143
# 	VALENCE-s19|Acc=0.78708|10-CV=0.49383|STD=0.09791|Time spend=132.56658267974854
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s20|Acc=0.775|10-CV=0.81983|STD=0.08703|Time spend=76.73931646347046
# 	VALENCE-s20|Acc=0.79583|10-CV=0.5865|STD=0.12008|Time spend=124.94280242919922
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.1|Time spend=73.05053615570068
# 	VALENCE-s21|Acc=0.69792|10-CV=0.474|STD=0.07845|Time spend=129.70090126991272
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s22|Acc=0.60875|10-CV=0.59533|STD=0.06321|Time spend=87.56917309761047
# 	VALENCE-s22|Acc=0.73292|10-CV=0.6685|STD=0.07826|Time spend=133.0420048236847
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s23|Acc=0.83333|10-CV=0.771|STD=0.08503|Time spend=76.55764532089233
# 	VALENCE-s23|Acc=0.83708|10-CV=0.58333|STD=0.10498|Time spend=126.18835210800171
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s24|Acc=0.825|10-CV=0.82|STD=0.07483|Time spend=69.71126794815063
# 	VALENCE-s24|Acc=0.75458|10-CV=0.56833|STD=0.08181|Time spend=122.07870221138
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s25|Acc=0.725|10-CV=0.73933|STD=0.12672|Time spend=77.47663068771362
# 	VALENCE-s25|Acc=0.68125|10-CV=0.44633|STD=0.10033|Time spend=135.2640676498413
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s26|Acc=0.71792|10-CV=0.53133|STD=0.09801|Time spend=88.48144316673279
# 	VALENCE-s26|Acc=0.68667|10-CV=0.59033|STD=0.11193|Time spend=139.4624798297882
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s27|Acc=0.85375|10-CV=0.62167|STD=0.09509|Time spend=78.4350438117981
# 	VALENCE-s27|Acc=0.80458|10-CV=0.65867|STD=0.11327|Time spend=120.0434181690216
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s28|Acc=0.68042|10-CV=0.46217|STD=0.07734|Time spend=88.7339997291565
# 	VALENCE-s28|Acc=0.73417|10-CV=0.52567|STD=0.10549|Time spend=137.09954571723938
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s29|Acc=0.72125|10-CV=0.54067|STD=0.08458|Time spend=83.78202295303345
# 	VALENCE-s29|Acc=0.76333|10-CV=0.5235|STD=0.07536|Time spend=136.68841218948364
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s30|Acc=0.765|10-CV=0.47967|STD=0.07602|Time spend=89.70457577705383
# 	VALENCE-s30|Acc=0.68167|10-CV=0.6025|STD=0.1339|Time spend=139.38293719291687
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s31|Acc=0.85708|10-CV=0.53267|STD=0.10037|Time spend=92.76178622245789
# 	VALENCE-s31|Acc=0.8375|10-CV=0.49933|STD=0.10068|Time spend=149.54147505760193
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s32|Acc=0.75375|10-CV=0.65233|STD=0.07889|Time spend=79.14824175834656
# 	VALENCE-s32|Acc=0.71708|10-CV=0.42033|STD=0.10232|Time spend=131.70638608932495
# AROUSAL|Acc=0.767578125|10-CV=0.6078541666666668|STD=0.09092423622219059
# VALENCE|Acc=0.7702083333333332|10-CV=0.5847239583333331|STD=0.09344996725170632

# %%
for text in reports:
    if(text == None): continue
    print(text)

accs.extend(accs_v)
cv_means.extend(cv_means_v)
cv_stds.extend(cv_stds_v)
print(f"TOTAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}")
# Out:
# 	AROUSAL-s01|Acc=0.89542|10-CV=0.55367|STD=0.11851|Time spend=109.13255429267883
# 	VALENCE-s01|Acc=0.90167|10-CV=0.4885|STD=0.0595|Time spend=174.95419669151306
# 	AROUSAL-s02|Acc=0.70333|10-CV=0.52817|STD=0.0708|Time spend=93.1835834980011
# 	VALENCE-s02|Acc=0.74625|10-CV=0.662|STD=0.09903|Time spend=143.70813846588135
# 	AROUSAL-s03|Acc=0.8|10-CV=0.73|STD=0.15524|Time spend=74.73655962944031
# -----WARNING: Model s03 failed to learn: sum(ans)=0.0 sum(y)=480.0 len(y)=2400
# 	VALENCE-s03|Acc=0.75875|10-CV=0.5405|STD=0.16141|Time spend=127.77436113357544
# 	AROUSAL-s04|Acc=0.72625|10-CV=0.5345|STD=0.10676|Time spend=86.01233530044556
# 	VALENCE-s04|Acc=0.75667|10-CV=0.563|STD=0.07111|Time spend=133.91743230819702
# 	AROUSAL-s05|Acc=0.72625|10-CV=0.46783|STD=0.0986|Time spend=91.03030467033386
# 	VALENCE-s05|Acc=0.73917|10-CV=0.55933|STD=0.07182|Time spend=143.22456979751587
# 	AROUSAL-s06|Acc=0.6925|10-CV=0.50617|STD=0.11754|Time spend=88.44585251808167
# 	VALENCE-s06|Acc=0.75042|10-CV=0.71883|STD=0.07451|Time spend=134.34594178199768
# 	AROUSAL-s07|Acc=0.82833|10-CV=0.588|STD=0.07728|Time spend=85.26484203338623
# 	VALENCE-s07|Acc=0.82292|10-CV=0.66283|STD=0.13512|Time spend=130.86327600479126
# 	AROUSAL-s08|Acc=0.84042|10-CV=0.42|STD=0.11451|Time spend=86.62875556945801
# 	VALENCE-s08|Acc=0.85708|10-CV=0.50133|STD=0.06464|Time spend=140.87181997299194
# 	AROUSAL-s09|Acc=0.73958|10-CV=0.49333|STD=0.08129|Time spend=81.36510443687439
# 	VALENCE-s09|Acc=0.77042|10-CV=0.62667|STD=0.09385|Time spend=126.49684929847717
# 	AROUSAL-s10|Acc=0.80458|10-CV=0.6015|STD=0.07473|Time spend=84.9338390827179
# 	VALENCE-s10|Acc=0.8625|10-CV=0.77367|STD=0.0736|Time spend=124.2664623260498
# 	AROUSAL-s11|Acc=0.67583|10-CV=0.56717|STD=0.05439|Time spend=81.67730498313904
# 	VALENCE-s11|Acc=0.69042|10-CV=0.53033|STD=0.12932|Time spend=131.80082988739014
# 	AROUSAL-s12|Acc=0.825|10-CV=0.83|STD=0.1005|Time spend=72.30015683174133
# -----WARNING: Model s12 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s12|Acc=0.74833|10-CV=0.53033|STD=0.11749|Time spend=123.34322381019592
# 	AROUSAL-s13|Acc=0.85|10-CV=0.84|STD=0.06633|Time spend=63.10807967185974
# -----WARNING: Model s13 failed to learn: sum(ans)=2400.0 sum(y)=2040.0 len(y)=2400
# 	VALENCE-s13|Acc=0.775|10-CV=0.69933|STD=0.08051|Time spend=106.21433281898499
# 	AROUSAL-s14|Acc=0.70042|10-CV=0.63033|STD=0.08913|Time spend=80.29607796669006
# 	VALENCE-s14|Acc=0.78958|10-CV=0.65633|STD=0.03735|Time spend=129.84347701072693
# 	AROUSAL-s15|Acc=0.82667|10-CV=0.51633|STD=0.09797|Time spend=84.28204584121704
# 	VALENCE-s15|Acc=0.88542|10-CV=0.75|STD=0.06066|Time spend=124.8164415359497
# 	AROUSAL-s16|Acc=0.80875|10-CV=0.50117|STD=0.06631|Time spend=84.05407285690308
# 	VALENCE-s16|Acc=0.78042|10-CV=0.64833|STD=0.09409|Time spend=130.70826888084412
# 	AROUSAL-s17|Acc=0.75208|10-CV=0.62933|STD=0.03682|Time spend=78.18584752082825
# 	VALENCE-s17|Acc=0.67833|10-CV=0.45933|STD=0.09546|Time spend=132.13649225234985
# 	AROUSAL-s18|Acc=0.71292|10-CV=0.52167|STD=0.11886|Time spend=82.87473154067993
# 	VALENCE-s18|Acc=0.82167|10-CV=0.69933|STD=0.06617|Time spend=120.6981680393219
# 	AROUSAL-s19|Acc=0.73792|10-CV=0.62617|STD=0.11685|Time spend=81.6785340309143
# 	VALENCE-s19|Acc=0.78708|10-CV=0.49383|STD=0.09791|Time spend=132.56658267974854
# 	AROUSAL-s20|Acc=0.775|10-CV=0.81983|STD=0.08703|Time spend=76.73931646347046
# -----WARNING: Model s20 failed to learn: sum(ans)=2400.0 sum(y)=1860.0 len(y)=2400
# 	VALENCE-s20|Acc=0.79583|10-CV=0.5865|STD=0.12008|Time spend=124.94280242919922
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.1|Time spend=73.05053615570068
# -----WARNING: Model s21 failed to learn: sum(ans)=2400.0 sum(y)=1920.0 len(y)=2400
# 	VALENCE-s21|Acc=0.69792|10-CV=0.474|STD=0.07845|Time spend=129.70090126991272
# 	AROUSAL-s22|Acc=0.60875|10-CV=0.59533|STD=0.06321|Time spend=87.56917309761047
# 	VALENCE-s22|Acc=0.73292|10-CV=0.6685|STD=0.07826|Time spend=133.0420048236847
# 	AROUSAL-s23|Acc=0.83333|10-CV=0.771|STD=0.08503|Time spend=76.55764532089233
# 	VALENCE-s23|Acc=0.83708|10-CV=0.58333|STD=0.10498|Time spend=126.18835210800171
# 	AROUSAL-s24|Acc=0.825|10-CV=0.82|STD=0.07483|Time spend=69.71126794815063
# -----WARNING: Model s24 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s24|Acc=0.75458|10-CV=0.56833|STD=0.08181|Time spend=122.07870221138
# 	AROUSAL-s25|Acc=0.725|10-CV=0.73933|STD=0.12672|Time spend=77.47663068771362
# -----WARNING: Model s25 failed to learn: sum(ans)=2400.0 sum(y)=1740.0 len(y)=2400
# 	VALENCE-s25|Acc=0.68125|10-CV=0.44633|STD=0.10033|Time spend=135.2640676498413
# 	AROUSAL-s26|Acc=0.71792|10-CV=0.53133|STD=0.09801|Time spend=88.48144316673279
# 	VALENCE-s26|Acc=0.68667|10-CV=0.59033|STD=0.11193|Time spend=139.4624798297882
# 	AROUSAL-s27|Acc=0.85375|10-CV=0.62167|STD=0.09509|Time spend=78.4350438117981
# 	VALENCE-s27|Acc=0.80458|10-CV=0.65867|STD=0.11327|Time spend=120.0434181690216
# 	AROUSAL-s28|Acc=0.68042|10-CV=0.46217|STD=0.07734|Time spend=88.7339997291565
# 	VALENCE-s28|Acc=0.73417|10-CV=0.52567|STD=0.10549|Time spend=137.09954571723938
# 	AROUSAL-s29|Acc=0.72125|10-CV=0.54067|STD=0.08458|Time spend=83.78202295303345
# 	VALENCE-s29|Acc=0.76333|10-CV=0.5235|STD=0.07536|Time spend=136.68841218948364
# 	AROUSAL-s30|Acc=0.765|10-CV=0.47967|STD=0.07602|Time spend=89.70457577705383
# 	VALENCE-s30|Acc=0.68167|10-CV=0.6025|STD=0.1339|Time spend=139.38293719291687
# 	AROUSAL-s31|Acc=0.85708|10-CV=0.53267|STD=0.10037|Time spend=92.76178622245789
# 	VALENCE-s31|Acc=0.8375|10-CV=0.49933|STD=0.10068|Time spend=149.54147505760193
# 	AROUSAL-s32|Acc=0.75375|10-CV=0.65233|STD=0.07889|Time spend=79.14824175834656
# 	VALENCE-s32|Acc=0.71708|10-CV=0.42033|STD=0.10232|Time spend=131.70638608932495
# AROUSAL|Acc=0.767578125|10-CV=0.6078541666666668|STD=0.09092423622219059
# VALENCE|Acc=0.7702083333333332|10-CV=0.5847239583333331|STD=0.09344996725170632
# TOTAL|Acc=0.7688932291666666|10-CV=0.5962890625000001|STD=0.09218710173694851

# %% [markdown]
# ### 2.4 $ \text{PLI}(j,k) =  \frac{1}{T} | \Sigma^{T}_{t=1} \text{sign}(Im[e^{i (\phi^{t}_{j} - \phi^{t}_{k})}])  | $
