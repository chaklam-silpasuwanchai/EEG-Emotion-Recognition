# %% [markdown]
# ## 1. Self Written Feature Extraction
#
# In this file, I will use self-written connectivity feature extraction.

# %%
import time
import mne
import numpy as np
from tqdm.notebook import tqdm

from components.dataset_jo import *

dataset = Dataset_subjectDependent('data')
dataset.set_segment(60)
# for filename in dataset.get_file_list():
#     data, labels, _ = dataset.get_data(filename, return_type='numpy')
#     print(filename, labels.shape, labels.sum(axis=0)/labels.shape[0]*100)
# Out:
# Found: 32 files

# %%
def train_model(X_ori,y_ori,groups_ori,filename=None, kernel='rbf',return_text=False):
    
    # Make a copy because I am paranoid
    X,y,groups = X_ori.copy(), y_ori.copy(), groups_ori.copy()

    from sklearn.svm import SVC
    from sklearn.model_selection import StratifiedShuffleSplit 
    from sklearn.model_selection import cross_val_score

    model = SVC(kernel=kernel,max_iter=50000)
    cv = StratifiedShuffleSplit(n_splits=10, train_size=0.75, random_state=0)
    cross = cross_val_score(model, X, y, cv=cv, n_jobs=8)
    
    # We probably dont need this
    model = SVC(kernel=kernel, max_iter=50000)
    model.fit(X, y)
    ans = model.predict(X)
    acc = sum(ans == y) / len(y)
    # If the model answer with all 0 or 1, we print this message
    text = None
    if( sum(ans) == len(y) or sum(ans) == 0 ): 
        text = f"-----WARNING: Model {filename} failed to learn: sum(ans)={sum(ans)} sum(y)={sum(y)} len(y)={len(y)}"
    if(return_text):
        return model, acc, cross, text
    else:
        print(text)
        return model, acc, cross


def pearson_correlation(x,y):
    """ x,y denoted the signal_x and signal_y following the equation """
    cov = np.cov(x, y)
    # print(cov)
    # [[ 8806859.74527069  8007149.0906219 ] ==> [[cov_xx, cov_xy]
    # [ 8007149.0906219  10396797.72458848]]      [cov_yx, cov_yy]]
    cov_xy = cov[0,1] # or cov[1,0]
    cov_xx = cov[0,0]
    cov_yy = cov[1,1]
    corr = cov_xy / ( cov_xx**0.5 * cov_yy**0.5  )
    return corr

def _cal(p_id, partial_data):
    # print(f"p_id:{p_id} - data to run {partial_data.shape}")
    from itertools import combinations
    pcc = []
    for index in range(partial_data.shape[0]):
        pcc_epoch = []
        for comb in combinations(list(range(partial_data.shape[1])), 2):
            pcc_ab = pearson_correlation(partial_data[index, comb[0], :], partial_data[index, comb[1], :]   )
            pcc_epoch.append(pcc_ab)
        pcc_epoch = np.hstack(pcc_epoch)
        pcc.append(pcc_epoch)
    pcc = np.vstack(pcc)
    return pcc

def calculate_pcc(data, n_jobs=8):
    """ 
    Input: Expect data to have (n_epochs, n_channels, n_samples)
    Output: (n_epochs, n_conn ) => n_conn = n_channels!/(2!(n_channels-2)!)
    """
    from multiprocessing import Pool

    try:
        t_out = 60000
        pool = Pool()
        p_list = []
        ans_list = []
        num_p = n_jobs
        indices = np.array_split(np.arange(data.shape[0]), num_p)
        for p_id in range(num_p):
            p_list.append(pool.apply_async(_cal, [p_id, data[indices[p_id]] ]))
        for p_id in range(num_p):
            ans_list.append( p_list[p_id].get(timeout=t_out) )
        # ans_list
    except e:
        print(e)
    finally:
        print("========= close ========")
        pool.close() 
        pool.terminate()
    return np.vstack(ans_list)

# %%
data, labels, groups = dataset.get_data('s01', stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
data_csd = mne.preprocessing.compute_current_source_density(data)
pcc = calculate_pcc(data_csd.get_data())
pcc.shape
# Out:
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# (2400, 496)

# %% [markdown]
# ## 2. Connectivity

# %% [markdown]
# ### 2.1 $ \text{PCC}_{\text{time}}(i,j) = \frac{\text{Cov}[\mathbf{X}_i, \mathbf{X}_j]}{\sigma_{\mathbf{X}_i} \sigma_{\mathbf{X}_j}} $

# %%
accs, cv_means, cv_stds = [],[],[]
accs_v, cv_means_v, cv_stds_v = [],[],[]
reports = []
for filename in (pbar := tqdm(dataset.get_file_list())):
    start = time.time()
    pbar.set_description(filename)
    data, labels, groups = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
    data_csd = mne.preprocessing.compute_current_source_density(data)
    pcc = calculate_pcc(data_csd.get_data())
    _,acc,cross,train_report = train_model(pcc, labels.squeeze(), groups, filename=filename, return_text=True)
    report = f"\tAROUSAL-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs.append(acc)
    cv_means.append(cross.mean())
    cv_stds.append(cross.std())

    _, labels_v, groups_v = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_VALENCE, return_type='mne', sfreq=128)
    _,acc,cross,train_report = train_model(pcc, labels_v.squeeze(), groups_v, filename=filename, return_text=True)
    report = f"\tVALENCE-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs_v.append(acc)
    cv_means_v.append(cross.mean())
    cv_stds_v.append(cross.std())
    # break
    # count+=1
    # if(count == 5): break
report = f"AROUSAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}"
print(report)
reports.append(report)
report = f"VALENCE|Acc={sum(accs_v)/len(accs_v)}|10-CV={sum(cv_means_v)/len(cv_means_v)}|STD={sum(cv_stds_v)/len(cv_stds_v)}"
print(report)
reports.append(report)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s09|Acc=0.60625|10-CV=0.60017|STD=0.0009|Time spend=33.4352240562439
# 	VALENCE-s09|Acc=0.62083|10-CV=0.61667|STD=0.01398|Time spend=46.04914402961731
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s19|Acc=0.675|10-CV=0.675|STD=0.0|Time spend=29.94568943977356
# 	VALENCE-s19|Acc=0.61375|10-CV=0.6025|STD=0.01502|Time spend=40.618797063827515
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s17|Acc=0.60208|10-CV=0.60017|STD=0.00203|Time spend=31.794206619262695
# 	VALENCE-s17|Acc=0.55|10-CV=0.54983|STD=0.0005|Time spend=42.96705198287964
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s28|Acc=0.55333|10-CV=0.55083|STD=0.00396|Time spend=33.38937020301819
# 	VALENCE-s28|Acc=0.625|10-CV=0.625|STD=0.0|Time spend=43.77236580848694
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s07|Acc=0.67333|10-CV=0.66783|STD=0.01366|Time spend=30.494722604751587
# 	VALENCE-s07|Acc=0.70292|10-CV=0.70067|STD=0.00153|Time spend=39.30493474006653
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s11|Acc=0.625|10-CV=0.625|STD=0.0|Time spend=35.21210050582886
# 	VALENCE-s11|Acc=0.61542|10-CV=0.60783|STD=0.00422|Time spend=47.51074481010437
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s25|Acc=0.725|10-CV=0.725|STD=0.0|Time spend=31.307119369506836
# 	VALENCE-s25|Acc=0.52917|10-CV=0.521|STD=0.01078|Time spend=45.38002896308899
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s24|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=28.25956678390503
# 	VALENCE-s24|Acc=0.57292|10-CV=0.56167|STD=0.01256|Time spend=41.00353932380676
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s04|Acc=0.60208|10-CV=0.60067|STD=0.00133|Time spend=33.56092047691345
# 	VALENCE-s04|Acc=0.60042|10-CV=0.6|STD=0.0|Time spend=45.4615638256073
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s16|Acc=0.68208|10-CV=0.643|STD=0.0114|Time spend=34.6611430644989
# 	VALENCE-s16|Acc=0.71417|10-CV=0.69733|STD=0.01153|Time spend=42.68095278739929
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s29|Acc=0.64|10-CV=0.63317|STD=0.0032|Time spend=32.95184087753296
# 	VALENCE-s29|Acc=0.6425|10-CV=0.62117|STD=0.01509|Time spend=45.15113306045532
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s26|Acc=0.5875|10-CV=0.57467|STD=0.01215|Time spend=35.451151609420776
# 	VALENCE-s26|Acc=0.65|10-CV=0.65|STD=0.0|Time spend=46.55673885345459
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s15|Acc=0.68792|10-CV=0.65717|STD=0.014|Time spend=40.957834243774414
# 	VALENCE-s15|Acc=0.75|10-CV=0.72767|STD=0.01287|Time spend=51.29856610298157
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=34.16512131690979
# 	VALENCE-s21|Acc=0.525|10-CV=0.525|STD=0.0|Time spend=46.796302318573
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s30|Acc=0.58125|10-CV=0.566|STD=0.00987|Time spend=34.93367052078247
# 	VALENCE-s30|Acc=0.675|10-CV=0.675|STD=0.0|Time spend=44.44305229187012
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s27|Acc=0.72208|10-CV=0.7|STD=0.00511|Time spend=39.12521457672119
# 	VALENCE-s27|Acc=0.75|10-CV=0.75|STD=0.00075|Time spend=47.37078237533569
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s31|Acc=0.69417|10-CV=0.65583|STD=0.01915|Time spend=38.784398555755615
# 	VALENCE-s31|Acc=0.64167|10-CV=0.60233|STD=0.01564|Time spend=50.794657945632935
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s10|Acc=0.63042|10-CV=0.592|STD=0.02188|Time spend=35.4853081703186
# 	VALENCE-s10|Acc=0.78833|10-CV=0.77467|STD=0.01746|Time spend=45.28066444396973
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s22|Acc=0.6|10-CV=0.6|STD=0.0|Time spend=37.27373814582825
# 	VALENCE-s22|Acc=0.62792|10-CV=0.624|STD=0.01373|Time spend=48.65073275566101
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s18|Acc=0.62542|10-CV=0.625|STD=0.0|Time spend=38.76257944107056
# 	VALENCE-s18|Acc=0.72083|10-CV=0.71133|STD=0.01597|Time spend=48.7407591342926
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s02|Acc=0.62083|10-CV=0.614|STD=0.00831|Time spend=37.202386140823364
# 	VALENCE-s02|Acc=0.59125|10-CV=0.58417|STD=0.02593|Time spend=50.50786018371582
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s20|Acc=0.775|10-CV=0.775|STD=0.0|Time spend=34.89012861251831
# 	VALENCE-s20|Acc=0.66667|10-CV=0.65517|STD=0.02042|Time spend=46.2471444606781
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s06|Acc=0.61125|10-CV=0.60233|STD=0.00611|Time spend=39.76330804824829
# 	VALENCE-s06|Acc=0.75|10-CV=0.75|STD=0.0|Time spend=49.57226014137268
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s23|Acc=0.75125|10-CV=0.75|STD=0.0|Time spend=36.871928215026855
# 	VALENCE-s23|Acc=0.73375|10-CV=0.70617|STD=0.00703|Time spend=47.6612343788147
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s03|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=35.92526435852051
# 	VALENCE-s03|Acc=0.55042|10-CV=0.55017|STD=0.0005|Time spend=50.4774854183197
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s05|Acc=0.57417|10-CV=0.56033|STD=0.01696|Time spend=42.995197057724
# 	VALENCE-s05|Acc=0.60208|10-CV=0.60033|STD=0.00067|Time spend=55.74359178543091
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s12|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=35.260091066360474
# 	VALENCE-s12|Acc=0.63917|10-CV=0.61383|STD=0.01483|Time spend=48.132304191589355
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s32|Acc=0.675|10-CV=0.675|STD=0.0|Time spend=41.99437856674194
# 	VALENCE-s32|Acc=0.60083|10-CV=0.57683|STD=0.01397|Time spend=55.58277750015259
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s08|Acc=0.61583|10-CV=0.586|STD=0.00573|Time spend=41.9524405002594
# 	VALENCE-s08|Acc=0.65667|10-CV=0.62|STD=0.02348|Time spend=55.17759585380554
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s01|Acc=0.71042|10-CV=0.661|STD=0.01511|Time spend=42.03586387634277
# 	VALENCE-s01|Acc=0.67917|10-CV=0.5955|STD=0.02001|Time spend=55.42995595932007
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s13|Acc=0.85|10-CV=0.85|STD=0.0|Time spend=34.567086935043335
# 	VALENCE-s13|Acc=0.6475|10-CV=0.64517|STD=0.01114|Time spend=46.708749532699585
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s14|Acc=0.675|10-CV=0.675|STD=0.0|Time spend=43.464874029159546
# 	VALENCE-s14|Acc=0.62667|10-CV=0.60367|STD=0.02172|Time spend=55.70815992355347
# AROUSAL|Acc=0.6756770833333335|10-CV=0.6653177083333335|STD=0.005340040625495117
# VALENCE|Acc=0.6456250000000001|10-CV=0.6326458333333334|STD=0.01004151067426304

# %%
for text in reports:
    if(text == None): continue
    print(text)
# Out:
# 	AROUSAL-s01|Acc=0.71042|10-CV=0.53583|STD=0.12882|Time spend=24.649158477783203
# 	VALENCE-s01|Acc=0.67917|10-CV=0.47867|STD=0.07076|Time spend=36.57502794265747
# 	AROUSAL-s02|Acc=0.62083|10-CV=0.55067|STD=0.09966|Time spend=28.401918411254883
# 	VALENCE-s02|Acc=0.59125|10-CV=0.47917|STD=0.10006|Time spend=40.15917253494263
# 	AROUSAL-s03|Acc=0.8|10-CV=0.73|STD=0.15524|Time spend=22.932647466659546
# -----WARNING: Model s03 failed to learn: sum(ans)=0.0 sum(y)=480.0 len(y)=2400
# 	VALENCE-s03|Acc=0.55042|10-CV=0.43967|STD=0.12141|Time spend=34.696168661117554
# 	AROUSAL-s04|Acc=0.60208|10-CV=0.52133|STD=0.20422|Time spend=28.39444637298584
# 	VALENCE-s04|Acc=0.60042|10-CV=0.4905|STD=0.18738|Time spend=39.192758321762085
# 	AROUSAL-s05|Acc=0.57417|10-CV=0.42483|STD=0.1069|Time spend=28.865741968154907
# 	VALENCE-s05|Acc=0.60208|10-CV=0.58633|STD=0.08869|Time spend=40.79992604255676
# 	AROUSAL-s06|Acc=0.61125|10-CV=0.5235|STD=0.14029|Time spend=27.70300030708313
# 	VALENCE-s06|Acc=0.75|10-CV=0.72|STD=0.07483|Time spend=36.020861864089966
# -----WARNING: Model s06 failed to learn: sum(ans)=2400.0 sum(y)=1800.0 len(y)=2400
# 	AROUSAL-s07|Acc=0.67333|10-CV=0.6235|STD=0.09409|Time spend=27.26369047164917
# 	VALENCE-s07|Acc=0.70292|10-CV=0.65833|STD=0.12437|Time spend=35.81617546081543
# 	AROUSAL-s08|Acc=0.61583|10-CV=0.41367|STD=0.10197|Time spend=27.816514253616333
# 	VALENCE-s08|Acc=0.65667|10-CV=0.5|STD=0.084|Time spend=39.18985295295715
# 	AROUSAL-s09|Acc=0.60625|10-CV=0.539|STD=0.11824|Time spend=28.036547422409058
# 	VALENCE-s09|Acc=0.62083|10-CV=0.52067|STD=0.14504|Time spend=39.28894805908203
# 	AROUSAL-s10|Acc=0.63042|10-CV=0.506|STD=0.08261|Time spend=27.75631618499756
# 	VALENCE-s10|Acc=0.78833|10-CV=0.73417|STD=0.07562|Time spend=37.16130995750427
# 	AROUSAL-s11|Acc=0.625|10-CV=0.6045|STD=0.06822|Time spend=26.712167024612427
# -----WARNING: Model s11 failed to learn: sum(ans)=0.0 sum(y)=900.0 len(y)=2400
# 	VALENCE-s11|Acc=0.61542|10-CV=0.53883|STD=0.15023|Time spend=37.390262603759766
# 	AROUSAL-s12|Acc=0.825|10-CV=0.83|STD=0.1005|Time spend=24.46749711036682
# -----WARNING: Model s12 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s12|Acc=0.63917|10-CV=0.45483|STD=0.14481|Time spend=35.49541163444519
# 	AROUSAL-s13|Acc=0.85|10-CV=0.84|STD=0.06633|Time spend=22.472914218902588
# -----WARNING: Model s13 failed to learn: sum(ans)=2400.0 sum(y)=2040.0 len(y)=2400
# 	VALENCE-s13|Acc=0.6475|10-CV=0.572|STD=0.07999|Time spend=33.113943338394165
# 	AROUSAL-s14|Acc=0.675|10-CV=0.65|STD=0.10247|Time spend=27.358490467071533
# -----WARNING: Model s14 failed to learn: sum(ans)=2400.0 sum(y)=1620.0 len(y)=2400
# 	VALENCE-s14|Acc=0.62667|10-CV=0.51133|STD=0.08787|Time spend=38.618101358413696
# 	AROUSAL-s15|Acc=0.68792|10-CV=0.47417|STD=0.10481|Time spend=28.036670923233032
# 	VALENCE-s15|Acc=0.75|10-CV=0.68267|STD=0.06071|Time spend=36.89628267288208
# 	AROUSAL-s16|Acc=0.68208|10-CV=0.45433|STD=0.10993|Time spend=28.46721911430359
# 	VALENCE-s16|Acc=0.71417|10-CV=0.641|STD=0.08687|Time spend=38.011072874069214
# 	AROUSAL-s17|Acc=0.60208|10-CV=0.54783|STD=0.0775|Time spend=27.40619730949402
# 	VALENCE-s17|Acc=0.55|10-CV=0.41333|STD=0.08757|Time spend=39.45033669471741
# -----WARNING: Model s17 failed to learn: sum(ans)=2400.0 sum(y)=1320.0 len(y)=2400
# 	AROUSAL-s18|Acc=0.62542|10-CV=0.545|STD=0.104|Time spend=27.338106632232666
# 	VALENCE-s18|Acc=0.72083|10-CV=0.63067|STD=0.12225|Time spend=36.56553363800049
# 	AROUSAL-s19|Acc=0.675|10-CV=0.62717|STD=0.129|Time spend=26.412465810775757
# -----WARNING: Model s19 failed to learn: sum(ans)=2400.0 sum(y)=1620.0 len(y)=2400
# 	VALENCE-s19|Acc=0.61375|10-CV=0.453|STD=0.12522|Time spend=37.28353810310364
# 	AROUSAL-s20|Acc=0.775|10-CV=0.82|STD=0.08718|Time spend=25.5428946018219
# -----WARNING: Model s20 failed to learn: sum(ans)=2400.0 sum(y)=1860.0 len(y)=2400
# 	VALENCE-s20|Acc=0.66667|10-CV=0.53767|STD=0.14521|Time spend=35.71930265426636
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.1|Time spend=25.300756216049194
# -----WARNING: Model s21 failed to learn: sum(ans)=2400.0 sum(y)=1920.0 len(y)=2400
# 	VALENCE-s21|Acc=0.525|10-CV=0.37883|STD=0.08466|Time spend=37.66263961791992
# -----WARNING: Model s21 failed to learn: sum(ans)=2400.0 sum(y)=1260.0 len(y)=2400
# 	AROUSAL-s22|Acc=0.6|10-CV=0.61|STD=0.07|Time spend=28.486467123031616
# -----WARNING: Model s22 failed to learn: sum(ans)=2400.0 sum(y)=1440.0 len(y)=2400
# 	VALENCE-s22|Acc=0.62792|10-CV=0.59883|STD=0.09632|Time spend=39.81468176841736
# 	AROUSAL-s23|Acc=0.75125|10-CV=0.77083|STD=0.08733|Time spend=24.24478054046631
# 	VALENCE-s23|Acc=0.73375|10-CV=0.58217|STD=0.10233|Time spend=33.569995403289795
# 	AROUSAL-s24|Acc=0.825|10-CV=0.82|STD=0.07483|Time spend=24.019882678985596
# -----WARNING: Model s24 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s24|Acc=0.57292|10-CV=0.4295|STD=0.18271|Time spend=36.122246980667114
# 	AROUSAL-s25|Acc=0.725|10-CV=0.74|STD=0.12806|Time spend=25.663275480270386
# -----WARNING: Model s25 failed to learn: sum(ans)=2400.0 sum(y)=1740.0 len(y)=2400
# 	VALENCE-s25|Acc=0.52917|10-CV=0.3825|STD=0.10034|Time spend=37.90600824356079
# 	AROUSAL-s26|Acc=0.5875|10-CV=0.53517|STD=0.11713|Time spend=28.945760488510132
# 	VALENCE-s26|Acc=0.65|10-CV=0.62|STD=0.14|Time spend=39.63161063194275
# -----WARNING: Model s26 failed to learn: sum(ans)=2400.0 sum(y)=1560.0 len(y)=2400
# 	AROUSAL-s27|Acc=0.72208|10-CV=0.62817|STD=0.09782|Time spend=25.709702730178833
# 	VALENCE-s27|Acc=0.75|10-CV=0.667|STD=0.12287|Time spend=32.784738302230835
# -----WARNING: Model s27 failed to learn: sum(ans)=2400.0 sum(y)=1800.0 len(y)=2400
# 	AROUSAL-s28|Acc=0.55333|10-CV=0.4355|STD=0.14079|Time spend=29.69543695449829
# 	VALENCE-s28|Acc=0.625|10-CV=0.57317|STD=0.15652|Time spend=40.32295083999634
# -----WARNING: Model s28 failed to learn: sum(ans)=2400.0 sum(y)=1500.0 len(y)=2400
# 	AROUSAL-s29|Acc=0.64|10-CV=0.53017|STD=0.08703|Time spend=27.482006311416626
# 	VALENCE-s29|Acc=0.6425|10-CV=0.538|STD=0.09315|Time spend=38.51368308067322
# 	AROUSAL-s30|Acc=0.58125|10-CV=0.4605|STD=0.06845|Time spend=28.50289011001587
# 	VALENCE-s30|Acc=0.675|10-CV=0.62|STD=0.14697|Time spend=38.12424039840698
# -----WARNING: Model s30 failed to learn: sum(ans)=2400.0 sum(y)=1620.0 len(y)=2400
# 	AROUSAL-s31|Acc=0.69417|10-CV=0.58117|STD=0.14086|Time spend=27.92600679397583
# 	VALENCE-s31|Acc=0.64167|10-CV=0.49|STD=0.10733|Time spend=38.89612078666687
# 	AROUSAL-s32|Acc=0.675|10-CV=0.74067|STD=0.12892|Time spend=26.653971433639526
# -----WARNING: Model s32 failed to learn: sum(ans)=2400.0 sum(y)=1620.0 len(y)=2400
# 	VALENCE-s32|Acc=0.60083|10-CV=0.43167|STD=0.11934|Time spend=37.84248924255371
# AROUSAL|Acc=0.6756770833333335|10-CV=0.606671875|STD=0.10697493467807011
# VALENCE|Acc=0.645625|10-CV=0.5423281249999999|STD=0.11298288071662489

# %%
accs.extend(accs_v)
cv_means.extend(cv_means_v)
cv_stds.extend(cv_stds_v)
print(f"TOTAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}")
# Out:
# TOTAL|Acc=0.6472066885964911|10-CV=0.6343654057017551|STD=0.00979406488222259

# %% [markdown]
# ### 2.2 $ \text{PCC}_{freq} (i,j) = \frac{\text{Cov}[\hat{\mathbf{X}}_i, \hat{\mathbf{X}}_j]}{\sigma_{\hat{\mathbf{X}}_i} \sigma_{\hat{\mathbf{X}}_j}} $

# %%
def calculate_fft(signal, sfreq):
    """ signal: can be 1D array of (n_sample,) or 2D array of (n_signal, n_sample)  """
    number_sample = signal.shape[-1]

    # the result will be a complex number. We can obtain the magnitude using `absolute`
    magnitude = np.abs(np.fft.fft(signal))
    # scale the result
    magnitude = magnitude / (number_sample/2)
    # Selecting the range
    magnitude = magnitude.T[:number_sample//2].T
    freq_range = np.fft.fftfreq(number_sample, d=1/sfreq)[:number_sample//2]

    return magnitude, freq_range

# %%
accs, cv_means, cv_stds = [],[],[]
accs_v, cv_means_v, cv_stds_v = [],[],[]
reports = []
for filename in (pbar := tqdm(dataset.get_file_list())):
    start = time.time()
    pbar.set_description(filename)
    data, labels, groups = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
    
    data_csd = mne.preprocessing.compute_current_source_density(data)
    magnitude, freq_range = calculate_fft(data_csd.get_data(), 128)
    pcc = calculate_pcc(magnitude)
    _,acc,cross,train_report = train_model(pcc, labels.squeeze(), groups, filename=filename, return_text=True)
    report = f"\tAROUSAL-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs.append(acc)
    cv_means.append(cross.mean())
    cv_stds.append(cross.std())

    _, labels_v, groups_v = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_VALENCE, return_type='mne', sfreq=128)
    _,acc,cross,train_report = train_model(pcc, labels_v.squeeze(), groups_v, filename=filename, return_text=True)
    report = f"\tVALENCE-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs_v.append(acc)
    cv_means_v.append(cross.mean())
    cv_stds_v.append(cross.std())
    # break
    # count+=1
    # if(count == 5): break
report = f"AROUSAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}"
print(report)
reports.append(report)
report = f"VALENCE|Acc={sum(accs_v)/len(accs_v)}|10-CV={sum(cv_means_v)/len(cv_means_v)}|STD={sum(cv_stds_v)/len(cv_stds_v)}"
print(report)
reports.append(report)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s09|Acc=0.65792|10-CV=0.6205|STD=0.01085|Time spend=50.36061072349548
# 	VALENCE-s09|Acc=0.67792|10-CV=0.63817|STD=0.01161|Time spend=65.66573977470398
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s19|Acc=0.68833|10-CV=0.67867|STD=0.00452|Time spend=55.59354519844055
# 	VALENCE-s19|Acc=0.6925|10-CV=0.606|STD=0.01254|Time spend=67.668137550354
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s17|Acc=0.67042|10-CV=0.65367|STD=0.01653|Time spend=49.55806279182434
# 	VALENCE-s17|Acc=0.59917|10-CV=0.56267|STD=0.01093|Time spend=62.91363191604614
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s28|Acc=0.58875|10-CV=0.554|STD=0.00496|Time spend=49.26823949813843
# 	VALENCE-s28|Acc=0.63583|10-CV=0.62617|STD=0.00299|Time spend=61.37085151672363
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s07|Acc=0.75583|10-CV=0.65917|STD=0.01745|Time spend=47.76533794403076
# 	VALENCE-s07|Acc=0.79|10-CV=0.72367|STD=0.00869|Time spend=58.30316948890686
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s11|Acc=0.65667|10-CV=0.64233|STD=0.00517|Time spend=48.72523903846741
# 	VALENCE-s11|Acc=0.65958|10-CV=0.64217|STD=0.00907|Time spend=60.64424777030945
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s25|Acc=0.725|10-CV=0.725|STD=0.0|Time spend=47.75992798805237
# 	VALENCE-s25|Acc=0.615|10-CV=0.55767|STD=0.02093|Time spend=61.122910022735596
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s24|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=43.96115517616272
# 	VALENCE-s24|Acc=0.65917|10-CV=0.564|STD=0.01422|Time spend=57.31309223175049
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s04|Acc=0.66083|10-CV=0.6225|STD=0.01076|Time spend=43.57878756523132
# 	VALENCE-s04|Acc=0.65833|10-CV=0.62017|STD=0.01497|Time spend=54.858824014663696
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s16|Acc=0.74458|10-CV=0.62417|STD=0.0167|Time spend=48.81018924713135
# 	VALENCE-s16|Acc=0.75042|10-CV=0.7025|STD=0.01389|Time spend=66.71343684196472
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s29|Acc=0.68792|10-CV=0.642|STD=0.00852|Time spend=60.76878809928894
# 	VALENCE-s29|Acc=0.69625|10-CV=0.61067|STD=0.01265|Time spend=73.5368504524231
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s26|Acc=0.67292|10-CV=0.58633|STD=0.01447|Time spend=57.984264850616455
# 	VALENCE-s26|Acc=0.67917|10-CV=0.65233|STD=0.00461|Time spend=77.44467306137085
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s15|Acc=0.77333|10-CV=0.67183|STD=0.01214|Time spend=78.55225491523743
# 	VALENCE-s15|Acc=0.81208|10-CV=0.74867|STD=0.01453|Time spend=88.7600450515747
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=66.07905769348145
# 	VALENCE-s21|Acc=0.63083|10-CV=0.5495|STD=0.01821|Time spend=79.7319176197052
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s30|Acc=0.68|10-CV=0.58817|STD=0.01452|Time spend=65.62070798873901
# 	VALENCE-s30|Acc=0.67542|10-CV=0.67467|STD=0.00067|Time spend=85.19185876846313
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s27|Acc=0.79167|10-CV=0.71167|STD=0.00975|Time spend=62.574835777282715
# 	VALENCE-s27|Acc=0.79958|10-CV=0.76767|STD=0.00396|Time spend=71.66288018226624
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s31|Acc=0.77875|10-CV=0.62517|STD=0.01715|Time spend=59.115723848342896
# 	VALENCE-s31|Acc=0.75542|10-CV=0.616|STD=0.02642|Time spend=77.97841548919678
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s10|Acc=0.72375|10-CV=0.63133|STD=0.00859|Time spend=54.81183218955994
# 	VALENCE-s10|Acc=0.81792|10-CV=0.77833|STD=0.02055|Time spend=63.03508806228638
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s22|Acc=0.60042|10-CV=0.6|STD=0.0|Time spend=37.31053066253662
# 	VALENCE-s22|Acc=0.64917|10-CV=0.62683|STD=0.01646|Time spend=48.16805553436279
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s18|Acc=0.67875|10-CV=0.65067|STD=0.00981|Time spend=36.47054362297058
# 	VALENCE-s18|Acc=0.78042|10-CV=0.72783|STD=0.02037|Time spend=58.25208830833435
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s02|Acc=0.65208|10-CV=0.61733|STD=0.0134|Time spend=86.53595662117004
# 	VALENCE-s02|Acc=0.64042|10-CV=0.59483|STD=0.02125|Time spend=114.74573421478271
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s20|Acc=0.775|10-CV=0.775|STD=0.0|Time spend=77.83895945549011
# 	VALENCE-s20|Acc=0.74958|10-CV=0.64683|STD=0.01705|Time spend=96.13012099266052
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s06|Acc=0.68083|10-CV=0.60867|STD=0.00977|Time spend=53.91687226295471
# 	VALENCE-s06|Acc=0.75083|10-CV=0.75|STD=0.0|Time spend=69.07689189910889
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s23|Acc=0.7675|10-CV=0.75067|STD=0.00133|Time spend=62.54665184020996
# 	VALENCE-s23|Acc=0.78292|10-CV=0.69383|STD=0.00928|Time spend=76.5152440071106
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s03|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=52.014121294021606
# 	VALENCE-s03|Acc=0.67917|10-CV=0.5945|STD=0.01128|Time spend=69.65651607513428
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s05|Acc=0.64458|10-CV=0.565|STD=0.01934|Time spend=93.62176704406738
# 	VALENCE-s05|Acc=0.66167|10-CV=0.61617|STD=0.0083|Time spend=115.91637682914734
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s12|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=100.45675683021545
# 	VALENCE-s12|Acc=0.69625|10-CV=0.627|STD=0.015|Time spend=127.60650897026062
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s32|Acc=0.70917|10-CV=0.681|STD=0.00436|Time spend=67.62734031677246
# 	VALENCE-s32|Acc=0.66458|10-CV=0.59133|STD=0.01035|Time spend=86.15736722946167
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s08|Acc=0.74875|10-CV=0.589|STD=0.00998|Time spend=60.09469723701477
# 	VALENCE-s08|Acc=0.74458|10-CV=0.612|STD=0.0243|Time spend=73.13199710845947
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s01|Acc=0.83458|10-CV=0.64117|STD=0.01449|Time spend=67.70610547065735
# 	VALENCE-s01|Acc=0.84583|10-CV=0.55633|STD=0.01433|Time spend=85.23976635932922
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s13|Acc=0.85|10-CV=0.85|STD=0.0|Time spend=75.30195784568787
# 	VALENCE-s13|Acc=0.69792|10-CV=0.64817|STD=0.01713|Time spend=93.1205689907074
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s14|Acc=0.67583|10-CV=0.67483|STD=0.0005|Time spend=67.8265950679779
# 	VALENCE-s14|Acc=0.70208|10-CV=0.60583|STD=0.01695|Time spend=84.1968183517456
# AROUSAL|Acc=0.7226302083333335|10-CV=0.6715572916666667|STD=0.007970848561636133
# VALENCE|Acc=0.7078125000000001|10-CV=0.6416406250000001|STD=0.01323369620263818

# %%
for text in reports:
    if(text == None): continue
    print(text)

accs.extend(accs_v)
cv_means.extend(cv_means_v)
cv_stds.extend(cv_stds_v)
print(f"TOTAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}")
# Out:
# 	AROUSAL-s09|Acc=0.65792|10-CV=0.6205|STD=0.01085|Time spend=50.36061072349548
# 	VALENCE-s09|Acc=0.67792|10-CV=0.63817|STD=0.01161|Time spend=65.66573977470398
# 	AROUSAL-s19|Acc=0.68833|10-CV=0.67867|STD=0.00452|Time spend=55.59354519844055
# 	VALENCE-s19|Acc=0.6925|10-CV=0.606|STD=0.01254|Time spend=67.668137550354
# 	AROUSAL-s17|Acc=0.67042|10-CV=0.65367|STD=0.01653|Time spend=49.55806279182434
# 	VALENCE-s17|Acc=0.59917|10-CV=0.56267|STD=0.01093|Time spend=62.91363191604614
# 	AROUSAL-s28|Acc=0.58875|10-CV=0.554|STD=0.00496|Time spend=49.26823949813843
# 	VALENCE-s28|Acc=0.63583|10-CV=0.62617|STD=0.00299|Time spend=61.37085151672363
# 	AROUSAL-s07|Acc=0.75583|10-CV=0.65917|STD=0.01745|Time spend=47.76533794403076
# 	VALENCE-s07|Acc=0.79|10-CV=0.72367|STD=0.00869|Time spend=58.30316948890686
# 	AROUSAL-s11|Acc=0.65667|10-CV=0.64233|STD=0.00517|Time spend=48.72523903846741
# 	VALENCE-s11|Acc=0.65958|10-CV=0.64217|STD=0.00907|Time spend=60.64424777030945
# 	AROUSAL-s25|Acc=0.725|10-CV=0.725|STD=0.0|Time spend=47.75992798805237
# -----WARNING: Model s25 failed to learn: sum(ans)=2400.0 sum(y)=1740.0 len(y)=2400
# 	VALENCE-s25|Acc=0.615|10-CV=0.55767|STD=0.02093|Time spend=61.122910022735596
# 	AROUSAL-s24|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=43.96115517616272
# -----WARNING: Model s24 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s24|Acc=0.65917|10-CV=0.564|STD=0.01422|Time spend=57.31309223175049
# 	AROUSAL-s04|Acc=0.66083|10-CV=0.6225|STD=0.01076|Time spend=43.57878756523132
# 	VALENCE-s04|Acc=0.65833|10-CV=0.62017|STD=0.01497|Time spend=54.858824014663696
# 	AROUSAL-s16|Acc=0.74458|10-CV=0.62417|STD=0.0167|Time spend=48.81018924713135
# 	VALENCE-s16|Acc=0.75042|10-CV=0.7025|STD=0.01389|Time spend=66.71343684196472
# 	AROUSAL-s29|Acc=0.68792|10-CV=0.642|STD=0.00852|Time spend=60.76878809928894
# 	VALENCE-s29|Acc=0.69625|10-CV=0.61067|STD=0.01265|Time spend=73.5368504524231
# 	AROUSAL-s26|Acc=0.67292|10-CV=0.58633|STD=0.01447|Time spend=57.984264850616455
# 	VALENCE-s26|Acc=0.67917|10-CV=0.65233|STD=0.00461|Time spend=77.44467306137085
# 	AROUSAL-s15|Acc=0.77333|10-CV=0.67183|STD=0.01214|Time spend=78.55225491523743
# 	VALENCE-s15|Acc=0.81208|10-CV=0.74867|STD=0.01453|Time spend=88.7600450515747
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=66.07905769348145
# -----WARNING: Model s21 failed to learn: sum(ans)=2400.0 sum(y)=1920.0 len(y)=2400
# 	VALENCE-s21|Acc=0.63083|10-CV=0.5495|STD=0.01821|Time spend=79.7319176197052
# 	AROUSAL-s30|Acc=0.68|10-CV=0.58817|STD=0.01452|Time spend=65.62070798873901
# 	VALENCE-s30|Acc=0.67542|10-CV=0.67467|STD=0.00067|Time spend=85.19185876846313
# 	AROUSAL-s27|Acc=0.79167|10-CV=0.71167|STD=0.00975|Time spend=62.574835777282715
# 	VALENCE-s27|Acc=0.79958|10-CV=0.76767|STD=0.00396|Time spend=71.66288018226624
# 	AROUSAL-s31|Acc=0.77875|10-CV=0.62517|STD=0.01715|Time spend=59.115723848342896
# 	VALENCE-s31|Acc=0.75542|10-CV=0.616|STD=0.02642|Time spend=77.97841548919678
# 	AROUSAL-s10|Acc=0.72375|10-CV=0.63133|STD=0.00859|Time spend=54.81183218955994
# 	VALENCE-s10|Acc=0.81792|10-CV=0.77833|STD=0.02055|Time spend=63.03508806228638
# 	AROUSAL-s22|Acc=0.60042|10-CV=0.6|STD=0.0|Time spend=37.31053066253662
# 	VALENCE-s22|Acc=0.64917|10-CV=0.62683|STD=0.01646|Time spend=48.16805553436279
# 	AROUSAL-s18|Acc=0.67875|10-CV=0.65067|STD=0.00981|Time spend=36.47054362297058
# 	VALENCE-s18|Acc=0.78042|10-CV=0.72783|STD=0.02037|Time spend=58.25208830833435
# 	AROUSAL-s02|Acc=0.65208|10-CV=0.61733|STD=0.0134|Time spend=86.53595662117004
# 	VALENCE-s02|Acc=0.64042|10-CV=0.59483|STD=0.02125|Time spend=114.74573421478271
# 	AROUSAL-s20|Acc=0.775|10-CV=0.775|STD=0.0|Time spend=77.83895945549011
# -----WARNING: Model s20 failed to learn: sum(ans)=2400.0 sum(y)=1860.0 len(y)=2400
# 	VALENCE-s20|Acc=0.74958|10-CV=0.64683|STD=0.01705|Time spend=96.13012099266052
# 	AROUSAL-s06|Acc=0.68083|10-CV=0.60867|STD=0.00977|Time spend=53.91687226295471
# 	VALENCE-s06|Acc=0.75083|10-CV=0.75|STD=0.0|Time spend=69.07689189910889
# 	AROUSAL-s23|Acc=0.7675|10-CV=0.75067|STD=0.00133|Time spend=62.54665184020996
# 	VALENCE-s23|Acc=0.78292|10-CV=0.69383|STD=0.00928|Time spend=76.5152440071106
# 	AROUSAL-s03|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=52.014121294021606
# -----WARNING: Model s03 failed to learn: sum(ans)=0.0 sum(y)=480.0 len(y)=2400
# 	VALENCE-s03|Acc=0.67917|10-CV=0.5945|STD=0.01128|Time spend=69.65651607513428
# 	AROUSAL-s05|Acc=0.64458|10-CV=0.565|STD=0.01934|Time spend=93.62176704406738
# 	VALENCE-s05|Acc=0.66167|10-CV=0.61617|STD=0.0083|Time spend=115.91637682914734
# 	AROUSAL-s12|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=100.45675683021545
# -----WARNING: Model s12 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s12|Acc=0.69625|10-CV=0.627|STD=0.015|Time spend=127.60650897026062
# 	AROUSAL-s32|Acc=0.70917|10-CV=0.681|STD=0.00436|Time spend=67.62734031677246
# 	VALENCE-s32|Acc=0.66458|10-CV=0.59133|STD=0.01035|Time spend=86.15736722946167
# 	AROUSAL-s08|Acc=0.74875|10-CV=0.589|STD=0.00998|Time spend=60.09469723701477
# 	VALENCE-s08|Acc=0.74458|10-CV=0.612|STD=0.0243|Time spend=73.13199710845947
# 	AROUSAL-s01|Acc=0.83458|10-CV=0.64117|STD=0.01449|Time spend=67.70610547065735
# 	VALENCE-s01|Acc=0.84583|10-CV=0.55633|STD=0.01433|Time spend=85.23976635932922
# 	AROUSAL-s13|Acc=0.85|10-CV=0.85|STD=0.0|Time spend=75.30195784568787
# -----WARNING: Model s13 failed to learn: sum(ans)=2400.0 sum(y)=2040.0 len(y)=2400
# 	VALENCE-s13|Acc=0.69792|10-CV=0.64817|STD=0.01713|Time spend=93.1205689907074
# 	AROUSAL-s14|Acc=0.67583|10-CV=0.67483|STD=0.0005|Time spend=67.8265950679779
# 	VALENCE-s14|Acc=0.70208|10-CV=0.60583|STD=0.01695|Time spend=84.1968183517456
# AROUSAL|Acc=0.7226302083333335|10-CV=0.6715572916666667|STD=0.007970848561636133
# VALENCE|Acc=0.7078125000000001|10-CV=0.6416406250000001|STD=0.01323369620263818
# TOTAL|Acc=0.7152213541666667|10-CV=0.6565989583333334|STD=0.010602272382137156

# %% [markdown]
# ### 2.3 $ \text{PLV}(j,k) = \frac{1}{T} | \Sigma^{T}_{t=1} e^{i(\phi^{t}_{j} - \phi^{t}_{k})}   | $

# %%
# bands = [(0,4), (4,8), (8,12), (12,30), (30,64)]
def calculate_stft(signals, sfreq):
    from scipy import signal
    f_range, t_range, Z = signal.stft(signals, sfreq, nperseg=sfreq//10, nfft=sfreq)
    magnitude = np.abs(Z) 
    phase = np.angle(Z)
    return magnitude, phase, f_range, t_range

def PLV_stft(p_id, phase):
    # (32, 65, 12) => (channels, freqs, times)
    # print(f"p_id:{p_id} - data to run {phase.shape}")
    print(phase.shape)
    from itertools import combinations
    plv = []
    # count = 0
    for index in range(phase.shape[0]):
        plv_epoch = []
        for comb in combinations(list(range(phase.shape[1])), 2):
            # shape = (65,12)
            phase_a, phase_b = phase[index, comb[0]], phase[index, comb[1]]
            phase_diff = phase_a - phase_b
            # sum along the time size
            plv_ab = np.abs(np.average(np.exp(complex(0,1) * phase_diff), axis=1))
            plv_epoch.append(plv_ab)
        plv_epoch = np.vstack(plv_epoch)
        # print(plv_epoch.shape) => (300, 32, 65, 23)
        plv_epoch_5 = np.concatenate([ plv_epoch[:,0:4].mean(axis=1).reshape(-1,1),
                                        plv_epoch[:,4:8].mean(axis=1).reshape(-1,1),
                                        plv_epoch[:,8:12].mean(axis=1).reshape(-1,1),
                                        plv_epoch[:,12:30].mean(axis=1).reshape(-1,1),
                                        plv_epoch[:,30:65].mean(axis=1).reshape(-1,1)], axis=0)
        plv.append(np.expand_dims(plv_epoch_5, axis=0))
        # count += 1
        # if(count == 3): break
    # shape (496, 65)
    # 496 is number of pairs that is not duplicate
    # 65 is number of phase of frequencies
    plv = np.vstack( plv )
    return plv.squeeze()

def calculate_plv(data, n_jobs=8):
    """ 
    Input: Expect data to have (n_epochs, n_channels, n_samples)
    Output: (n_epochs, n_conn, n_freqs ) => n_conn = n_channels!/(2!(n_channels-2)!)
    """
    from multiprocessing import Pool

    try:
        t_out = 60000
        pool = Pool()
        p_list = []
        ans_list = []
        num_p = n_jobs
        indices = np.array_split(np.arange(data.shape[0]), num_p)
        _, phase, _, _ = calculate_stft(data, 128)
        for p_id in range(num_p):
            p_list.append(pool.apply_async(PLV_stft, [p_id, phase[indices[p_id]] ]))
        for p_id in range(num_p):
            ans_list.append( p_list[p_id].get(timeout=t_out) )
        # ans_list
    finally:
        print("========= close ========")
        pool.close() 
        pool.terminate()
    return np.vstack(ans_list)

# %%
data, labels, groups = dataset.get_data('s01', stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
data_csd = mne.preprocessing.compute_current_source_density(data)
plv = calculate_plv(data_csd.get_data(), n_jobs=8)
# _, phase, _, _ = calculate_stft(data_csd.get_data(), 128)
# plv = PLV_stft(1, phase)
plv.shape
del(plv)
# Out:
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========

# %%
accs, cv_means, cv_stds = [],[],[]
accs_v, cv_means_v, cv_stds_v = [],[],[]
reports = []
for filename in (pbar := tqdm(dataset.get_file_list())):
    start = time.time()
    pbar.set_description(filename)
    data, labels, groups = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
    
    data_csd = mne.preprocessing.compute_current_source_density(data)

    plv = calculate_plv(data_csd.get_data(), n_jobs=8)

    _,acc,cross,train_report = train_model(plv, labels.squeeze(), groups, filename=filename, return_text=True)
    report = f"\tAROUSAL-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs.append(acc)
    cv_means.append(cross.mean())
    cv_stds.append(cross.std())

    _, labels_v, groups_v = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_VALENCE, return_type='mne', sfreq=128)
    _,acc,cross,train_report = train_model(plv, labels_v.squeeze(), groups_v, filename=filename, return_text=True)
    report = f"\tVALENCE-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs_v.append(acc)
    cv_means_v.append(cross.mean())
    cv_stds_v.append(cross.std())
    # break
    # count+=1
    # if(count == 5): break
report = f"AROUSAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}"
print(report)
reports.append(report)
report = f"VALENCE|Acc={sum(accs_v)/len(accs_v)}|10-CV={sum(cv_means_v)/len(cv_means_v)}|STD={sum(cv_stds_v)/len(cv_stds_v)}"
print(report)
reports.append(report)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s09|Acc=0.73958|10-CV=0.674|STD=0.01403|Time spend=948.3420503139496
# 	VALENCE-s09|Acc=0.77042|10-CV=0.734|STD=0.01515|Time spend=1086.4108264446259
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s19|Acc=0.73792|10-CV=0.69133|STD=0.00407|Time spend=277.81249713897705
# 	VALENCE-s19|Acc=0.78708|10-CV=0.656|STD=0.01352|Time spend=353.21989727020264
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s17|Acc=0.75208|10-CV=0.7015|STD=0.00804|Time spend=110.3167929649353
# 	VALENCE-s17|Acc=0.67833|10-CV=0.60933|STD=0.02265|Time spend=187.76707768440247
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s28|Acc=0.68042|10-CV=0.59133|STD=0.01183|Time spend=129.9256203174591
# 	VALENCE-s28|Acc=0.73417|10-CV=0.6705|STD=0.0096|Time spend=198.33644199371338
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s07|Acc=0.82833|10-CV=0.6835|STD=0.01237|Time spend=120.8293342590332
# 	VALENCE-s07|Acc=0.82292|10-CV=0.7425|STD=0.00889|Time spend=187.26276850700378
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s11|Acc=0.67583|10-CV=0.64433|STD=0.00876|Time spend=122.75873184204102
# 	VALENCE-s11|Acc=0.69042|10-CV=0.6525|STD=0.00911|Time spend=195.70947551727295
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s25|Acc=0.725|10-CV=0.725|STD=0.0|Time spend=111.27799916267395
# 	VALENCE-s25|Acc=0.68125|10-CV=0.605|STD=0.0166|Time spend=190.91181588172913
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s24|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=220.6598641872406
# 	VALENCE-s24|Acc=0.75458|10-CV=0.67567|STD=0.01212|Time spend=294.1026704311371
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s04|Acc=0.72625|10-CV=0.65267|STD=0.01397|Time spend=215.65577292442322
# 	VALENCE-s04|Acc=0.75667|10-CV=0.66983|STD=0.01937|Time spend=283.50916290283203
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s16|Acc=0.80875|10-CV=0.6805|STD=0.01862|Time spend=124.00120234489441
# 	VALENCE-s16|Acc=0.78042|10-CV=0.70567|STD=0.01096|Time spend=189.23126554489136
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s29|Acc=0.72125|10-CV=0.65083|STD=0.00935|Time spend=125.01844573020935
# 	VALENCE-s29|Acc=0.76333|10-CV=0.64467|STD=0.01782|Time spend=200.08863878250122
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s26|Acc=0.71792|10-CV=0.60783|STD=0.01211|Time spend=128.70105123519897
# 	VALENCE-s26|Acc=0.68667|10-CV=0.65433|STD=0.00335|Time spend=203.39920568466187
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s15|Acc=0.82667|10-CV=0.68|STD=0.01337|Time spend=128.0532968044281
# 	VALENCE-s15|Acc=0.88542|10-CV=0.7945|STD=0.01445|Time spend=184.19291710853577
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=106.66287040710449
# 	VALENCE-s21|Acc=0.69792|10-CV=0.5915|STD=0.01661|Time spend=184.14739727973938
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s30|Acc=0.765|10-CV=0.61867|STD=0.01597|Time spend=131.76889157295227
# 	VALENCE-s30|Acc=0.68167|10-CV=0.67567|STD=0.0017|Time spend=204.06878924369812
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s27|Acc=0.85375|10-CV=0.73283|STD=0.0131|Time spend=115.73226618766785
# 	VALENCE-s27|Acc=0.80458|10-CV=0.75583|STD=0.00359|Time spend=176.46483397483826
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s31|Acc=0.85708|10-CV=0.6465|STD=0.02355|Time spend=130.79363870620728
# 	VALENCE-s31|Acc=0.8375|10-CV=0.61433|STD=0.01546|Time spend=210.36158728599548
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s10|Acc=0.80458|10-CV=0.67933|STD=0.01405|Time spend=125.003591299057
# 	VALENCE-s10|Acc=0.8625|10-CV=0.80617|STD=0.01673|Time spend=179.8182966709137
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s22|Acc=0.60875|10-CV=0.60267|STD=0.00318|Time spend=129.7533369064331
# 	VALENCE-s22|Acc=0.73292|10-CV=0.70333|STD=0.01145|Time spend=194.69043374061584
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s18|Acc=0.71292|10-CV=0.66067|STD=0.00873|Time spend=122.07978367805481
# 	VALENCE-s18|Acc=0.82167|10-CV=0.76533|STD=0.02364|Time spend=175.45020461082458
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s02|Acc=0.70333|10-CV=0.6425|STD=0.01417|Time spend=125.92822074890137
# 	VALENCE-s02|Acc=0.74625|10-CV=0.70433|STD=0.01181|Time spend=191.71977710723877
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s20|Acc=0.775|10-CV=0.775|STD=0.0|Time spend=112.86955571174622
# 	VALENCE-s20|Acc=0.79583|10-CV=0.684|STD=0.01985|Time spend=180.2031271457672
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s06|Acc=0.6925|10-CV=0.6105|STD=0.01128|Time spend=130.22994089126587
# 	VALENCE-s06|Acc=0.75042|10-CV=0.75|STD=0.0|Time spend=196.2985589504242
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s23|Acc=0.83333|10-CV=0.76083|STD=0.00281|Time spend=109.05994963645935
# 	VALENCE-s23|Acc=0.83708|10-CV=0.7335|STD=0.01478|Time spend=179.61419034004211
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s03|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=105.81283164024353
# 	VALENCE-s03|Acc=0.75875|10-CV=0.64583|STD=0.01385|Time spend=177.63104271888733
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s05|Acc=0.72625|10-CV=0.615|STD=0.01929|Time spend=132.49872851371765
# 	VALENCE-s05|Acc=0.73917|10-CV=0.65767|STD=0.00659|Time spend=206.7809681892395
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s12|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=105.46692490577698
# 	VALENCE-s12|Acc=0.74833|10-CV=0.64667|STD=0.01677|Time spend=177.09520506858826
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s32|Acc=0.75375|10-CV=0.69617|STD=0.00803|Time spend=113.54448652267456
# 	VALENCE-s32|Acc=0.71708|10-CV=0.6135|STD=0.01359|Time spend=191.7024257183075
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s08|Acc=0.84042|10-CV=0.6225|STD=0.01694|Time spend=129.99863243103027
# 	VALENCE-s08|Acc=0.85708|10-CV=0.664|STD=0.01484|Time spend=206.6598105430603
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s01|Acc=0.89542|10-CV=0.67733|STD=0.01424|Time spend=125.70549440383911
# 	VALENCE-s01|Acc=0.90167|10-CV=0.60867|STD=0.00954|Time spend=206.6582396030426
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s13|Acc=0.85|10-CV=0.85|STD=0.0|Time spend=89.29362392425537
# 	VALENCE-s13|Acc=0.775|10-CV=0.75283|STD=0.00928|Time spend=149.85760617256165
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# (300, 32, 65, 23)
# ========= close ========
# 	AROUSAL-s14|Acc=0.70042|10-CV=0.67783|STD=0.00358|Time spend=113.75962710380554
# 	VALENCE-s14|Acc=0.78958|10-CV=0.7115|STD=0.01644|Time spend=181.1462481021881
# AROUSAL|Acc=0.767578125|10-CV=0.6906614583333333|STD=0.009232525137285164
# VALENCE|Acc=0.7702083333333333|10-CV=0.6843489583333333|STD=0.012816225409554668

# %%
for text in reports:
    if(text == None): continue
    print(text)

accs.extend(accs_v)
cv_means.extend(cv_means_v)
cv_stds.extend(cv_stds_v)
print(f"TOTAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}")
# Out:
# 	AROUSAL-s09|Acc=0.73958|10-CV=0.674|STD=0.01403|Time spend=948.3420503139496
# 	VALENCE-s09|Acc=0.77042|10-CV=0.734|STD=0.01515|Time spend=1086.4108264446259
# 	AROUSAL-s19|Acc=0.73792|10-CV=0.69133|STD=0.00407|Time spend=277.81249713897705
# 	VALENCE-s19|Acc=0.78708|10-CV=0.656|STD=0.01352|Time spend=353.21989727020264
# 	AROUSAL-s17|Acc=0.75208|10-CV=0.7015|STD=0.00804|Time spend=110.3167929649353
# 	VALENCE-s17|Acc=0.67833|10-CV=0.60933|STD=0.02265|Time spend=187.76707768440247
# 	AROUSAL-s28|Acc=0.68042|10-CV=0.59133|STD=0.01183|Time spend=129.9256203174591
# 	VALENCE-s28|Acc=0.73417|10-CV=0.6705|STD=0.0096|Time spend=198.33644199371338
# 	AROUSAL-s07|Acc=0.82833|10-CV=0.6835|STD=0.01237|Time spend=120.8293342590332
# 	VALENCE-s07|Acc=0.82292|10-CV=0.7425|STD=0.00889|Time spend=187.26276850700378
# 	AROUSAL-s11|Acc=0.67583|10-CV=0.64433|STD=0.00876|Time spend=122.75873184204102
# 	VALENCE-s11|Acc=0.69042|10-CV=0.6525|STD=0.00911|Time spend=195.70947551727295
# 	AROUSAL-s25|Acc=0.725|10-CV=0.725|STD=0.0|Time spend=111.27799916267395
# -----WARNING: Model s25 failed to learn: sum(ans)=2400.0 sum(y)=1740.0 len(y)=2400
# 	VALENCE-s25|Acc=0.68125|10-CV=0.605|STD=0.0166|Time spend=190.91181588172913
# 	AROUSAL-s24|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=220.6598641872406
# -----WARNING: Model s24 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s24|Acc=0.75458|10-CV=0.67567|STD=0.01212|Time spend=294.1026704311371
# 	AROUSAL-s04|Acc=0.72625|10-CV=0.65267|STD=0.01397|Time spend=215.65577292442322
# 	VALENCE-s04|Acc=0.75667|10-CV=0.66983|STD=0.01937|Time spend=283.50916290283203
# 	AROUSAL-s16|Acc=0.80875|10-CV=0.6805|STD=0.01862|Time spend=124.00120234489441
# 	VALENCE-s16|Acc=0.78042|10-CV=0.70567|STD=0.01096|Time spend=189.23126554489136
# 	AROUSAL-s29|Acc=0.72125|10-CV=0.65083|STD=0.00935|Time spend=125.01844573020935
# 	VALENCE-s29|Acc=0.76333|10-CV=0.64467|STD=0.01782|Time spend=200.08863878250122
# 	AROUSAL-s26|Acc=0.71792|10-CV=0.60783|STD=0.01211|Time spend=128.70105123519897
# 	VALENCE-s26|Acc=0.68667|10-CV=0.65433|STD=0.00335|Time spend=203.39920568466187
# 	AROUSAL-s15|Acc=0.82667|10-CV=0.68|STD=0.01337|Time spend=128.0532968044281
# 	VALENCE-s15|Acc=0.88542|10-CV=0.7945|STD=0.01445|Time spend=184.19291710853577
# 	AROUSAL-s21|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=106.66287040710449
# -----WARNING: Model s21 failed to learn: sum(ans)=2400.0 sum(y)=1920.0 len(y)=2400
# 	VALENCE-s21|Acc=0.69792|10-CV=0.5915|STD=0.01661|Time spend=184.14739727973938
# 	AROUSAL-s30|Acc=0.765|10-CV=0.61867|STD=0.01597|Time spend=131.76889157295227
# 	VALENCE-s30|Acc=0.68167|10-CV=0.67567|STD=0.0017|Time spend=204.06878924369812
# 	AROUSAL-s27|Acc=0.85375|10-CV=0.73283|STD=0.0131|Time spend=115.73226618766785
# 	VALENCE-s27|Acc=0.80458|10-CV=0.75583|STD=0.00359|Time spend=176.46483397483826
# 	AROUSAL-s31|Acc=0.85708|10-CV=0.6465|STD=0.02355|Time spend=130.79363870620728
# 	VALENCE-s31|Acc=0.8375|10-CV=0.61433|STD=0.01546|Time spend=210.36158728599548
# 	AROUSAL-s10|Acc=0.80458|10-CV=0.67933|STD=0.01405|Time spend=125.003591299057
# 	VALENCE-s10|Acc=0.8625|10-CV=0.80617|STD=0.01673|Time spend=179.8182966709137
# 	AROUSAL-s22|Acc=0.60875|10-CV=0.60267|STD=0.00318|Time spend=129.7533369064331
# 	VALENCE-s22|Acc=0.73292|10-CV=0.70333|STD=0.01145|Time spend=194.69043374061584
# 	AROUSAL-s18|Acc=0.71292|10-CV=0.66067|STD=0.00873|Time spend=122.07978367805481
# 	VALENCE-s18|Acc=0.82167|10-CV=0.76533|STD=0.02364|Time spend=175.45020461082458
# 	AROUSAL-s02|Acc=0.70333|10-CV=0.6425|STD=0.01417|Time spend=125.92822074890137
# 	VALENCE-s02|Acc=0.74625|10-CV=0.70433|STD=0.01181|Time spend=191.71977710723877
# 	AROUSAL-s20|Acc=0.775|10-CV=0.775|STD=0.0|Time spend=112.86955571174622
# -----WARNING: Model s20 failed to learn: sum(ans)=2400.0 sum(y)=1860.0 len(y)=2400
# 	VALENCE-s20|Acc=0.79583|10-CV=0.684|STD=0.01985|Time spend=180.2031271457672
# 	AROUSAL-s06|Acc=0.6925|10-CV=0.6105|STD=0.01128|Time spend=130.22994089126587
# 	VALENCE-s06|Acc=0.75042|10-CV=0.75|STD=0.0|Time spend=196.2985589504242
# 	AROUSAL-s23|Acc=0.83333|10-CV=0.76083|STD=0.00281|Time spend=109.05994963645935
# 	VALENCE-s23|Acc=0.83708|10-CV=0.7335|STD=0.01478|Time spend=179.61419034004211
# 	AROUSAL-s03|Acc=0.8|10-CV=0.8|STD=0.0|Time spend=105.81283164024353
# -----WARNING: Model s03 failed to learn: sum(ans)=0.0 sum(y)=480.0 len(y)=2400
# 	VALENCE-s03|Acc=0.75875|10-CV=0.64583|STD=0.01385|Time spend=177.63104271888733
# 	AROUSAL-s05|Acc=0.72625|10-CV=0.615|STD=0.01929|Time spend=132.49872851371765
# 	VALENCE-s05|Acc=0.73917|10-CV=0.65767|STD=0.00659|Time spend=206.7809681892395
# 	AROUSAL-s12|Acc=0.825|10-CV=0.825|STD=0.0|Time spend=105.46692490577698
# -----WARNING: Model s12 failed to learn: sum(ans)=2400.0 sum(y)=1980.0 len(y)=2400
# 	VALENCE-s12|Acc=0.74833|10-CV=0.64667|STD=0.01677|Time spend=177.09520506858826
# 	AROUSAL-s32|Acc=0.75375|10-CV=0.69617|STD=0.00803|Time spend=113.54448652267456
# 	VALENCE-s32|Acc=0.71708|10-CV=0.6135|STD=0.01359|Time spend=191.7024257183075
# 	AROUSAL-s08|Acc=0.84042|10-CV=0.6225|STD=0.01694|Time spend=129.99863243103027
# 	VALENCE-s08|Acc=0.85708|10-CV=0.664|STD=0.01484|Time spend=206.6598105430603
# 	AROUSAL-s01|Acc=0.89542|10-CV=0.67733|STD=0.01424|Time spend=125.70549440383911
# 	VALENCE-s01|Acc=0.90167|10-CV=0.60867|STD=0.00954|Time spend=206.6582396030426
# 	AROUSAL-s13|Acc=0.85|10-CV=0.85|STD=0.0|Time spend=89.29362392425537
# -----WARNING: Model s13 failed to learn: sum(ans)=2400.0 sum(y)=2040.0 len(y)=2400
# 	VALENCE-s13|Acc=0.775|10-CV=0.75283|STD=0.00928|Time spend=149.85760617256165
# 	AROUSAL-s14|Acc=0.70042|10-CV=0.67783|STD=0.00358|Time spend=113.75962710380554
# 	VALENCE-s14|Acc=0.78958|10-CV=0.7115|STD=0.01644|Time spend=181.1462481021881
# AROUSAL|Acc=0.767578125|10-CV=0.6906614583333333|STD=0.009232525137285164
# VALENCE|Acc=0.7702083333333333|10-CV=0.6843489583333333|STD=0.012816225409554668
# TOTAL|Acc=0.7688932291666666|10-CV=0.6875052083333333|STD=0.011024375273419916

# %% [markdown]
# ### 2.4 $ \text{PLI}(j,k) =  \frac{1}{T} | \Sigma^{T}_{t=1} \text{sign}(Im[e^{i (\phi^{t}_{j} - \phi^{t}_{k})}])  | $

# %%
# bands = [(0,4), (4,8), (8,12), (12,30), (30,64)]
def calculate_stft(signals, sfreq):
    from scipy import signal
    f_range, t_range, Z = signal.stft(signals, sfreq, nperseg=sfreq//10, nfft=sfreq)
    magnitude = np.abs(Z) 
    phase = np.angle(Z)
    return magnitude, phase, f_range, t_range

def PLI_stft(p_id, phase):
    # (32, 65, 12) => (channels, freqs, times)
    # print(f"p_id:{p_id} - data to run {phase.shape}")
    from itertools import combinations
    pli = []
    # count = 0
    for index in range(phase.shape[0]):
        pli_epoch = []
        for comb in combinations(list(range(phase.shape[1])), 2):
            # shape = (65,12)
            phase_a, phase_b = phase[index, comb[0]], phase[index, comb[1]]
            phase_diff = phase_a - phase_b
            # sum along the time size
            pli_ab = np.abs(np.average(   np.sign(np.imag(   np.exp(complex(0,1) * phase_diff) ))  , axis=1))
            pli_epoch.append(pli_ab)
        pli_epoch = np.vstack(pli_epoch)
        pli_epoch_5 = np.concatenate([ pli_epoch[:,0:4].mean(axis=1).reshape(-1,1),
                                        pli_epoch[:,4:8].mean(axis=1).reshape(-1,1),
                                        pli_epoch[:,8:12].mean(axis=1).reshape(-1,1),
                                        pli_epoch[:,12:30].mean(axis=1).reshape(-1,1),
                                        pli_epoch[:,30:65].mean(axis=1).reshape(-1,1)], axis=0)
        pli.append(np.expand_dims(pli_epoch_5, axis=0))
        # count += 1
        # if(count == 3): break
    # shape (496, 65)
    # 496 is number of pairs that is not duplicate
    # 65 is number of phase of frequencies
    pli = np.vstack( pli )
    return pli.squeeze()

def calculate_pli(data, n_jobs=8):
    """ 
    Input: Expect data to have (n_epochs, n_channels, n_samples)
    Output: (n_epochs, n_conn, n_freqs ) => n_conn = n_channels!/(2!(n_channels-2)!)
    """
    from multiprocessing import Pool

    try:
        t_out = 60000
        pool = Pool()
        p_list = []
        ans_list = []
        num_p = n_jobs
        indices = np.array_split(np.arange(data.shape[0]), num_p)
        _, phase, _, _ = calculate_stft(data, 128)
        for p_id in range(num_p):
            p_list.append(pool.apply_async(PLI_stft, [p_id, phase[indices[p_id]] ]))
        for p_id in range(num_p):
            ans_list.append( p_list[p_id].get(timeout=t_out) )
        # ans_list
    finally:
        print("========= close ========")
        pool.close() 
        pool.terminate()
    return np.vstack(ans_list)

# %%
data, labels, groups = dataset.get_data('s01', stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
data_csd = mne.preprocessing.compute_current_source_density(data)
pli = calculate_pli(data_csd.get_data(), n_jobs=8)
# _, phase, _, _ = calculate_stft(data_csd.get_data(), 128)
# pli = pli_stft(1, phase)
print(pli.shape)
del(pli)
# Out:
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# (2400, 2480)

# %%
accs, cv_means, cv_stds = [],[],[]
accs_v, cv_means_v, cv_stds_v = [],[],[]
reports = []
for filename in (pbar := tqdm(dataset.get_file_list())):
    start = time.time()
    pbar.set_description(filename)
    data, labels, groups = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_AROUSAL, return_type='mne', sfreq=128)
    
    data_csd = mne.preprocessing.compute_current_source_density(data)

    pli = calculate_pli(data_csd.get_data(), n_jobs=8)

    _,acc,cross,train_report = train_model(pli, labels.squeeze(), groups, filename=filename, return_text=True)
    report = f"\tAROUSAL-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs.append(acc)
    cv_means.append(cross.mean())
    cv_stds.append(cross.std())

    _, labels_v, groups_v = dataset.get_data(filename, stimuli=Dataset_subjectDependent.STIMULI_VALENCE, return_type='mne', sfreq=128)
    _,acc,cross,train_report = train_model(pli, labels_v.squeeze(), groups_v, filename=filename, return_text=True)
    report = f"\tVALENCE-{filename}|Acc={round(acc,5)}|10-CV={round(cross.mean(),5)}|STD={round(cross.std(),5)}|Time spend={time.time() - start}"
    print(report)
    reports.append(report)
    reports.append(train_report)
    accs_v.append(acc)
    cv_means_v.append(cross.mean())
    cv_stds_v.append(cross.std())
    # break
    # count+=1
    # if(count == 5): break
report = f"AROUSAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}"
print(report)
reports.append(report)
report = f"VALENCE|Acc={sum(accs_v)/len(accs_v)}|10-CV={sum(cv_means_v)/len(cv_means_v)}|STD={sum(cv_stds_v)/len(cv_stds_v)}"
print(report)
reports.append(report)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s09|Acc=0.76792|10-CV=0.59533|STD=0.00314|Time spend=132.70519638061523
# 	VALENCE-s09|Acc=0.90667|10-CV=0.53883|STD=0.02438|Time spend=218.1479251384735
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s19|Acc=0.71542|10-CV=0.67483|STD=0.0005|Time spend=121.75163507461548
# 	VALENCE-s19|Acc=0.82833|10-CV=0.56333|STD=0.00901|Time spend=204.59139943122864
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s17|Acc=0.80292|10-CV=0.61033|STD=0.00983|Time spend=132.16715049743652
# 	VALENCE-s17|Acc=0.90583|10-CV=0.55|STD=0.0169|Time spend=218.91054964065552
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s28|Acc=0.92542|10-CV=0.53167|STD=0.0119|Time spend=134.61193656921387
# 	VALENCE-s28|Acc=0.84375|10-CV=0.62333|STD=0.00279|Time spend=220.23092770576477
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s07|Acc=0.9125|10-CV=0.623|STD=0.00515|Time spend=129.0194935798645
# 	VALENCE-s07|Acc=0.8475|10-CV=0.7|STD=0.0|Time spend=205.66868090629578
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s11|Acc=0.77583|10-CV=0.624|STD=0.00226|Time spend=132.0025942325592
# 	VALENCE-s11|Acc=0.78792|10-CV=0.597|STD=0.00393|Time spend=215.4134566783905
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s25|Acc=0.74958|10-CV=0.725|STD=0.0|Time spend=133.6463963985443
# 	VALENCE-s25|Acc=0.9125|10-CV=0.53517|STD=0.02062|Time spend=220.33082509040833
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s24|Acc=0.82917|10-CV=0.825|STD=0.0|Time spend=132.45227479934692
# 	VALENCE-s24|Acc=0.90375|10-CV=0.55367|STD=0.01648|Time spend=216.9211847782135
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s04|Acc=0.80333|10-CV=0.59783|STD=0.00522|Time spend=128.63855171203613
# 	VALENCE-s04|Acc=0.79292|10-CV=0.5965|STD=0.00383|Time spend=212.16141867637634
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s16|Acc=0.9775|10-CV=0.49167|STD=0.0164|Time spend=116.76318049430847
# 	VALENCE-s16|Acc=0.89417|10-CV=0.62317|STD=0.00189|Time spend=195.6292040348053
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s29|Acc=0.81125|10-CV=0.62133|STD=0.00296|Time spend=132.61697244644165
# 	VALENCE-s29|Acc=0.86542|10-CV=0.57283|STD=0.00879|Time spend=216.7589294910431
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s26|Acc=0.865|10-CV=0.56283|STD=0.01028|Time spend=130.42382311820984
# 	VALENCE-s26|Acc=0.77917|10-CV=0.6495|STD=0.0013|Time spend=212.68705081939697
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s15|Acc=0.96875|10-CV=0.48417|STD=0.01553|Time spend=135.28731083869934
# 	VALENCE-s15|Acc=0.97083|10-CV=0.52667|STD=0.01468|Time spend=221.23527145385742
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s21|Acc=0.81083|10-CV=0.8|STD=0.0|Time spend=127.16207337379456
# 	VALENCE-s21|Acc=0.94708|10-CV=0.508|STD=0.00977|Time spend=212.2434000968933
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s30|Acc=0.92542|10-CV=0.525|STD=0.01609|Time spend=133.95704770088196
# 	VALENCE-s30|Acc=0.75417|10-CV=0.675|STD=0.0|Time spend=216.3294894695282
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s27|Acc=0.87333|10-CV=0.675|STD=0.0|Time spend=138.26921916007996
# 	VALENCE-s27|Acc=0.8525|10-CV=0.75|STD=0.0|Time spend=217.44516372680664
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s31|Acc=0.9775|10-CV=0.53367|STD=0.01671|Time spend=142.2008352279663
# 	VALENCE-s31|Acc=0.95417|10-CV=0.56533|STD=0.01222|Time spend=229.46287298202515
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s10|Acc=0.94292|10-CV=0.55267|STD=0.01287|Time spend=133.3607199192047
# 	VALENCE-s10|Acc=0.9675|10-CV=0.53767|STD=0.0153|Time spend=218.2764298915863
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s22|Acc=0.76875|10-CV=0.59617|STD=0.00637|Time spend=129.65227222442627
# 	VALENCE-s22|Acc=0.86708|10-CV=0.54733|STD=0.01101|Time spend=216.5292670726776
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s18|Acc=0.83917|10-CV=0.6255|STD=0.00269|Time spend=131.76876878738403
# 	VALENCE-s18|Acc=0.87208|10-CV=0.6005|STD=0.00628|Time spend=217.53075170516968
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s02|Acc=0.82958|10-CV=0.61317|STD=0.00899|Time spend=128.10621547698975
# 	VALENCE-s02|Acc=0.89417|10-CV=0.53833|STD=0.01035|Time spend=213.9267556667328
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s20|Acc=0.82208|10-CV=0.775|STD=0.0|Time spend=128.79516863822937
# 	VALENCE-s20|Acc=0.9175|10-CV=0.583|STD=0.00971|Time spend=213.13362884521484
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s06|Acc=0.9125|10-CV=0.5685|STD=0.00841|Time spend=141.57041311264038
# 	VALENCE-s06|Acc=0.80042|10-CV=0.75|STD=0.0|Time spend=224.06633639335632
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s23|Acc=0.86042|10-CV=0.75|STD=0.0|Time spend=128.8548698425293
# 	VALENCE-s23|Acc=0.91083|10-CV=0.64967|STD=0.00067|Time spend=215.7871994972229
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s03|Acc=0.82833|10-CV=0.8|STD=0.0|Time spend=128.27302289009094
# 	VALENCE-s03|Acc=0.94458|10-CV=0.53|STD=0.01682|Time spend=213.62644410133362
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s05|Acc=0.85833|10-CV=0.504|STD=0.01313|Time spend=127.89515161514282
# 	VALENCE-s05|Acc=0.71958|10-CV=0.59867|STD=0.00256|Time spend=210.7653489112854
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s12|Acc=0.845|10-CV=0.825|STD=0.0|Time spend=140.3218469619751
# 	VALENCE-s12|Acc=0.97625|10-CV=0.51883|STD=0.01044|Time spend=236.22415781021118
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s32|Acc=0.80083|10-CV=0.675|STD=0.0|Time spend=140.16345930099487
# 	VALENCE-s32|Acc=0.95167|10-CV=0.51267|STD=0.01853|Time spend=234.4072926044464
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s08|Acc=0.94583|10-CV=0.5655|STD=0.01236|Time spend=143.37983751296997
# 	VALENCE-s08|Acc=0.95208|10-CV=0.56467|STD=0.01199|Time spend=235.23505640029907
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s01|Acc=0.92833|10-CV=0.60483|STD=0.00851|Time spend=138.36845207214355
# 	VALENCE-s01|Acc=0.98417|10-CV=0.51667|STD=0.01382|Time spend=231.99383878707886
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s13|Acc=0.85875|10-CV=0.85|STD=0.0|Time spend=131.56320595741272
# 	VALENCE-s13|Acc=0.89375|10-CV=0.559|STD=0.01131|Time spend=215.27799105644226
# Fitted sphere radius:         95.3 mm
# Origin head coordinates:      -0.8 15.1 45.3 mm
# Origin device coordinates:    -0.8 15.1 45.3 mm
# ========= close ========
# 	AROUSAL-s14|Acc=0.79417|10-CV=0.67517|STD=0.0009|Time spend=127.75288343429565
# 	VALENCE-s14|Acc=0.95875|10-CV=0.5015|STD=0.01235|Time spend=222.11380076408386
# AROUSAL|Acc=0.8539583333333333|10-CV=0.6400364583333334|STD=0.005944267654768601
# VALENCE|Acc=0.8861588541666667|10-CV=0.5824010416666667|STD=0.009304221809262004

# %%
for text in reports:
    if(text == None): continue
    print(text)

accs.extend(accs_v)
cv_means.extend(cv_means_v)
cv_stds.extend(cv_stds_v)
print(f"TOTAL|Acc={sum(accs)/len(accs)}|10-CV={sum(cv_means)/len(cv_means)}|STD={sum(cv_stds)/len(cv_stds)}")
# Out:
# 	AROUSAL-s09|Acc=0.76792|10-CV=0.59533|STD=0.00314|Time spend=132.70519638061523
# 	VALENCE-s09|Acc=0.90667|10-CV=0.53883|STD=0.02438|Time spend=218.1479251384735
# 	AROUSAL-s19|Acc=0.71542|10-CV=0.67483|STD=0.0005|Time spend=121.75163507461548
# 	VALENCE-s19|Acc=0.82833|10-CV=0.56333|STD=0.00901|Time spend=204.59139943122864
# 	AROUSAL-s17|Acc=0.80292|10-CV=0.61033|STD=0.00983|Time spend=132.16715049743652
# 	VALENCE-s17|Acc=0.90583|10-CV=0.55|STD=0.0169|Time spend=218.91054964065552
# 	AROUSAL-s28|Acc=0.92542|10-CV=0.53167|STD=0.0119|Time spend=134.61193656921387
# 	VALENCE-s28|Acc=0.84375|10-CV=0.62333|STD=0.00279|Time spend=220.23092770576477
# 	AROUSAL-s07|Acc=0.9125|10-CV=0.623|STD=0.00515|Time spend=129.0194935798645
# 	VALENCE-s07|Acc=0.8475|10-CV=0.7|STD=0.0|Time spend=205.66868090629578
# 	AROUSAL-s11|Acc=0.77583|10-CV=0.624|STD=0.00226|Time spend=132.0025942325592
# 	VALENCE-s11|Acc=0.78792|10-CV=0.597|STD=0.00393|Time spend=215.4134566783905
# 	AROUSAL-s25|Acc=0.74958|10-CV=0.725|STD=0.0|Time spend=133.6463963985443
# 	VALENCE-s25|Acc=0.9125|10-CV=0.53517|STD=0.02062|Time spend=220.33082509040833
# 	AROUSAL-s24|Acc=0.82917|10-CV=0.825|STD=0.0|Time spend=132.45227479934692
# 	VALENCE-s24|Acc=0.90375|10-CV=0.55367|STD=0.01648|Time spend=216.9211847782135
# 	AROUSAL-s04|Acc=0.80333|10-CV=0.59783|STD=0.00522|Time spend=128.63855171203613
# 	VALENCE-s04|Acc=0.79292|10-CV=0.5965|STD=0.00383|Time spend=212.16141867637634
# 	AROUSAL-s16|Acc=0.9775|10-CV=0.49167|STD=0.0164|Time spend=116.76318049430847
# 	VALENCE-s16|Acc=0.89417|10-CV=0.62317|STD=0.00189|Time spend=195.6292040348053
# 	AROUSAL-s29|Acc=0.81125|10-CV=0.62133|STD=0.00296|Time spend=132.61697244644165
# 	VALENCE-s29|Acc=0.86542|10-CV=0.57283|STD=0.00879|Time spend=216.7589294910431
# 	AROUSAL-s26|Acc=0.865|10-CV=0.56283|STD=0.01028|Time spend=130.42382311820984
# 	VALENCE-s26|Acc=0.77917|10-CV=0.6495|STD=0.0013|Time spend=212.68705081939697
# 	AROUSAL-s15|Acc=0.96875|10-CV=0.48417|STD=0.01553|Time spend=135.28731083869934
# 	VALENCE-s15|Acc=0.97083|10-CV=0.52667|STD=0.01468|Time spend=221.23527145385742
# 	AROUSAL-s21|Acc=0.81083|10-CV=0.8|STD=0.0|Time spend=127.16207337379456
# 	VALENCE-s21|Acc=0.94708|10-CV=0.508|STD=0.00977|Time spend=212.2434000968933
# 	AROUSAL-s30|Acc=0.92542|10-CV=0.525|STD=0.01609|Time spend=133.95704770088196
# 	VALENCE-s30|Acc=0.75417|10-CV=0.675|STD=0.0|Time spend=216.3294894695282
# 	AROUSAL-s27|Acc=0.87333|10-CV=0.675|STD=0.0|Time spend=138.26921916007996
# 	VALENCE-s27|Acc=0.8525|10-CV=0.75|STD=0.0|Time spend=217.44516372680664
# 	AROUSAL-s31|Acc=0.9775|10-CV=0.53367|STD=0.01671|Time spend=142.2008352279663
# 	VALENCE-s31|Acc=0.95417|10-CV=0.56533|STD=0.01222|Time spend=229.46287298202515
# 	AROUSAL-s10|Acc=0.94292|10-CV=0.55267|STD=0.01287|Time spend=133.3607199192047
# 	VALENCE-s10|Acc=0.9675|10-CV=0.53767|STD=0.0153|Time spend=218.2764298915863
# 	AROUSAL-s22|Acc=0.76875|10-CV=0.59617|STD=0.00637|Time spend=129.65227222442627
# 	VALENCE-s22|Acc=0.86708|10-CV=0.54733|STD=0.01101|Time spend=216.5292670726776
# 	AROUSAL-s18|Acc=0.83917|10-CV=0.6255|STD=0.00269|Time spend=131.76876878738403
# 	VALENCE-s18|Acc=0.87208|10-CV=0.6005|STD=0.00628|Time spend=217.53075170516968
# 	AROUSAL-s02|Acc=0.82958|10-CV=0.61317|STD=0.00899|Time spend=128.10621547698975
# 	VALENCE-s02|Acc=0.89417|10-CV=0.53833|STD=0.01035|Time spend=213.9267556667328
# 	AROUSAL-s20|Acc=0.82208|10-CV=0.775|STD=0.0|Time spend=128.79516863822937
# 	VALENCE-s20|Acc=0.9175|10-CV=0.583|STD=0.00971|Time spend=213.13362884521484
# 	AROUSAL-s06|Acc=0.9125|10-CV=0.5685|STD=0.00841|Time spend=141.57041311264038
# 	VALENCE-s06|Acc=0.80042|10-CV=0.75|STD=0.0|Time spend=224.06633639335632
# 	AROUSAL-s23|Acc=0.86042|10-CV=0.75|STD=0.0|Time spend=128.8548698425293
# 	VALENCE-s23|Acc=0.91083|10-CV=0.64967|STD=0.00067|Time spend=215.7871994972229
# 	AROUSAL-s03|Acc=0.82833|10-CV=0.8|STD=0.0|Time spend=128.27302289009094
# 	VALENCE-s03|Acc=0.94458|10-CV=0.53|STD=0.01682|Time spend=213.62644410133362
# 	AROUSAL-s05|Acc=0.85833|10-CV=0.504|STD=0.01313|Time spend=127.89515161514282
# 	VALENCE-s05|Acc=0.71958|10-CV=0.59867|STD=0.00256|Time spend=210.7653489112854
# 	AROUSAL-s12|Acc=0.845|10-CV=0.825|STD=0.0|Time spend=140.3218469619751
# 	VALENCE-s12|Acc=0.97625|10-CV=0.51883|STD=0.01044|Time spend=236.22415781021118
# 	AROUSAL-s32|Acc=0.80083|10-CV=0.675|STD=0.0|Time spend=140.16345930099487
# 	VALENCE-s32|Acc=0.95167|10-CV=0.51267|STD=0.01853|Time spend=234.4072926044464
# 	AROUSAL-s08|Acc=0.94583|10-CV=0.5655|STD=0.01236|Time spend=143.37983751296997
# 	VALENCE-s08|Acc=0.95208|10-CV=0.56467|STD=0.01199|Time spend=235.23505640029907
# 	AROUSAL-s01|Acc=0.92833|10-CV=0.60483|STD=0.00851|Time spend=138.36845207214355
# 	VALENCE-s01|Acc=0.98417|10-CV=0.51667|STD=0.01382|Time spend=231.99383878707886
# 	AROUSAL-s13|Acc=0.85875|10-CV=0.85|STD=0.0|Time spend=131.56320595741272
# 	VALENCE-s13|Acc=0.89375|10-CV=0.559|STD=0.01131|Time spend=215.27799105644226
# 	AROUSAL-s14|Acc=0.79417|10-CV=0.67517|STD=0.0009|Time spend=127.75288343429565
# 	VALENCE-s14|Acc=0.95875|10-CV=0.5015|STD=0.01235|Time spend=222.11380076408386
# AROUSAL|Acc=0.8539583333333333|10-CV=0.6400364583333334|STD=0.005944267654768601
# VALENCE|Acc=0.8861588541666667|10-CV=0.5824010416666667|STD=0.009304221809262004
# TOTAL|Acc=0.87005859375|10-CV=0.61121875|STD=0.007624244732015303
